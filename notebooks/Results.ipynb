# %% [markdown]
# ## Setup

# %%
import pathlib

import torch
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import utils
from data import MET_Data, get_transformation_function
from losses import ReconstructionLoss

# %%
old_format_maps = {"T": ["logcpm"], "E": ["pca-ipfx"], "M": ["arbors"]}

def get_latent(encoder, met_data, specimen_ids, formats):
    data = met_data.query(specimen_ids, formats = [tuple(formats)])
    torch_input = {form: torch.from_numpy(data[form]).float() for form in formats}
    latent = encoder(torch_input).detach().numpy()
    return (latent, data["specimen_ids"])

def get_experiment_reconstructions(exp_name, exp_dict, met_data, specimen_ids, trans_funcs, valid_modalities = []):
    valid_modalities = exp_dict["config"]["modalities"] if valid_modalities is None else valid_modalities
    modalities = set(valid_modalities) & set(exp_dict["config"]["modalities"])
    fold_recons = []
    folds = exp_dict["folds"]
    folds = dict(enumerate(folds, 1)) if type(folds) == list else folds
    for (i, fold) in folds.items():
        fold_recon = {}
        non_train_ids = specimen_ids[~np.isin(np.char.strip(specimen_ids), np.char.strip(fold["train_ids"]))]
        model = fold["best"] if "best" in fold else fold["model"].models
        for in_modal in modalities:
            for out_modal in modalities:
                if "formats" in exp_dict["config"]:
                    (in_formats, out_formats) = (exp_dict["config"]["formats"][in_modal], exp_dict["config"]["formats"][out_modal])
                else:
                    (in_formats, out_formats) = (old_format_maps[in_modal], old_format_maps[out_modal])
                valid_data = met_data.query(non_train_ids, formats = [tuple(in_formats + out_formats)])
                if len(valid_data[in_formats[0]]):
                    print(f"Generating {exp_name} - {i}: {in_modal} -> {out_modal}             ", end = "\r")
                    transformed = {form: trans_funcs.get(form, lambda x: x)(valid_data[form]) for form in in_formats}
                    input_data = {form: torch.from_numpy(array).float() for (form, array) in transformed.items()}
                    raw_recons = model(input_data, in_modal, [out_modal])[out_modal]
                    recons = {form: tensor.detach().numpy() for (form, tensor) in raw_recons.items()}
                    fold_recon[f"{in_modal}->{out_modal}"] = (recons, valid_data["specimen_id"])
        fold_recons.append(fold_recon)
    return fold_recons

def get_reconstruction_scores(exp_recon_dict, loss_func, met_data, trans_funcs, display_funcs = None):
    scores = {}
    for (modal_string, (recon_forms, recon_specimen_ids)) in exp_recon_dict.items():
        data = met_data.get_specimens(recon_specimen_ids)
        transformed = {form: trans_funcs.get(form, lambda x: x)(data[form]) for form in recon_forms}
        tensor_orig = {form: torch.from_numpy(array) for (form, array) in transformed.items()}
        tensor_recon = {form: torch.from_numpy(arr) for (form, arr) in recon_forms.items()}
        loss = loss_func.loss(tensor_orig, tensor_recon)
        display_func = (display_funcs.get(modal_string[-1], lambda x: x) if display_funcs else lambda x: x)
        scores[modal_string] = display_func(loss)
    return scores

def load_experiment(exp_type, base_dir, exp_info, checkpoints = False):
    if exp_type == "cca":
        exp_path = pathlib.Path(base_dir) / exp_info
        experiment = utils.load_pca_cca(exp_path)
        name = exp_info
    elif exp_type == "coupler":
        exp_path = pathlib.Path(base_dir) / exp_info
        experiment = utils.load_coupler_folds(exp_path, get_checkpoints = checkpoints)
        name = exp_info
    elif exp_type == "autoencoder":
        exp_path = pathlib.Path(base_dir) / exp_info
        experiment = utils.load_jit_folds(exp_path, get_checkpoints = checkpoints)
        name = exp_info
    elif exp_type == "forest":
        (exp_path, exp_name, merge_num) = exp_info
        experiment = utils.get_forest_AE(base_dir, exp_path, exp_name, merge_num)
        name = exp_name.replace("-", "_")
    else:
        raise ValueError(f'Experiment type "{exp_type}" not recognized.')
    return (experiment, name)

def generate_recon_plan(specified, targets, experiments):
    plan = {}
    if not specified:
        spec_targets = list(targets.keys())
    else:
        spec_targets = [tupl[0] for tupl in specified]
    for target in spec_targets:
        plan[target] = {}
        spec_groups = [tupl[1] for tupl in specified if tupl[0] == target and tupl[1] is not None]
        if not spec_groups:
            spec_groups = targets[target]["groups"]
        for group in spec_groups:
            spec_experiments = [tupl[2] for tupl in specified 
                                if tupl[0] == target and tupl[1] == group and tupl[2] is not None]
            if not spec_experiments:
                spec_experiments = list(experiments[group].keys())
            plan[target][group] = spec_experiments
    return plan

def run_recon_plan(plan, targets, met_data, loaded_experiments, previous = {}):
    for (target, groups_dict) in plan.items():
        print(f"\nRunning target {target}:")
        target_info = targets[target]
        specimen_ids = met_data.query(**target_info["query"], outputs = ["specimen_id"])["specimen_id"]
        loss_config = {"encoder_cross_grad": False, "device": "cpu", **target_info["loss"]}
        loss_func = ReconstructionLoss(loss_config, met_data, specimen_ids)
        trans_funcs = {form: get_transformation_function(params) for (form, params) in target_info["loss"]["transform"].items()}
        target_accs = previous.setdefault(target, {})
        for (group, experiments) in groups_dict.items():
            group_accs = target_accs.setdefault(group, {})
            for exp_name in experiments:
                exp_dict = loaded_experiments[group][exp_name]
                folds = get_experiment_reconstructions(exp_name, exp_dict, met_data, specimen_ids, trans_funcs, target_info["modalities"])
                group_accs[exp_name] = [get_reconstruction_scores(fold_dict, loss_func, met_data, trans_funcs, target_info["display"]) 
                                        for fold_dict in folds]
        print("\nComplete                                                       ")
    return previous

def compute_scores(reconstruction_accs):
    scores = {}
    for (target, target_dict) in reconstruction_accs.items():
        scores[target] = {}
        for (group, group_dict) in target_dict.items():
            scores[target][group] = {}
            for (exp_name, folds) in group_dict.items():
                modal_strings = [key for fold_dict in folds for key in fold_dict.keys()]
                means = {string: np.mean([fold[string] for fold in folds]) for string in modal_strings}
                stds = {string: np.std([fold[string] for fold in folds]) for string in modal_strings}
                scores[target][group][exp_name] = {"mean": means, "std": stds}
    return scores

def build_table(scores, column_info, groups, num_decimals, exps = None, style_map = None):
    (column_means, column_stds) = ({}, {})
    for (modal_string, target, col_label) in column_info:
        (column_means[col_label], column_stds[col_label]) = ({}, {})
        target_metrics = {exp_name:metrics for (group, group_dict) in scores[target].items() 
                         for (exp_name, metrics) in group_dict.items() if group in groups}
        column_means[col_label] = {exp_name: exp_dict["mean"].get(modal_string) 
                                   for (exp_name, exp_dict) in target_metrics.items()}
        column_stds[col_label] = {exp_name: exp_dict["std"].get(modal_string) 
                                  for (exp_name, exp_dict) in target_metrics.items()}
    mean_frame = pd.DataFrame(column_means).round(num_decimals).astype("string").fillna("--")
    std_frame = pd.DataFrame(column_stds).round(num_decimals).astype("string").fillna("")
    combined_frame = mean_frame + ("±" + std_frame).replace("±", "")
    combined_frame = combined_frame[~(combined_frame == "--").all(1)]
    if exps:
        combined_frame = combined_frame[combined_frame.index.isin(exps)]
        sorted_frame = combined_frame.sort_index(key = lambda series: series.map(lambda exp_name: exps.index(exp_name)))
    else:
        sorted_frame = combined_frame.sort_index(key = lambda series: series.map(lambda exp_name: groups.index(exp_name.split("-")[-1])))
    if style_map:
        sorted_frame = sorted_frame.style.applymap(style_map)
    return sorted_frame

# %% [markdown]
# ## Models

# %%
data_paths = {"patchseq": "../data/patchseq.hdf5",
              "EM": "../data/EM.hdf5",
              "EM_sholl": "../data/EM_sholl.hdf5",
              "smartseq": "../data/smartseq.hdf5",
              "10x": "../data/10x.hdf5",
              "trunc": "../data/patch_smart_trunc.hdf5"}
data_keys = {
    "logcpm": [["patchseq", "logcpm"], ["smartseq", "logcpm_aligned"]], #[["trunc", "logcpm"], ["10x", "logcpm_aligned"]],
    "pca-ipfx": [["patchseq", "pca-ipfx"]],
    "arbors": [["patchseq", "arbors"], ["EM", "arbors"]],
    "sholl": [["patchseq", "sholl"], ["EM_sholl", "sholl"]]}
met_data = MET_Data(data_paths, **data_keys)
for form in ["logcpm", "pca-ipfx", "arbors", "sholl"]:
    met_data.cache_data(form)
# Out:
# Caching logcpm...
# Caching pca-ipfx...
# Caching arbors...
# Caching sholl...

# %%
all_exp_info = {
    # "simple": {
    #     "type": "autoencoder",
    #     "dir": "../results/old_results/simple_loss",
    #     "exps": ["coupled", "cross", "cross_coupled"]
    # },
    # "alignment": {
    #     "type": "autoencoder",
    #     "dir": "../results/alignment",
    #     "exps": ["t_patchseq", "t_both", "met_patch", "met_both", "met_full"]},
    # "maxweight": {
    #     "type": "autoencoder",
    #     "dir": "../results/maxweight",
    #     "exps": ["t_arm", "e_arm", "m_arm", "t_e", "e_t", "m_e", "e_m", "t_m", "m_t"]},
    # "weighted": {
    #     "type": "autoencoder",
    #     "dir": "../results/weighted",
    #     "exps": ["met_et_2x", "met_et_4x", "met_et_4x_10d", "met_et_4x_MET", "met_et_4x_patch"]},
    # "vanilla": {
    #     "type": "autoencoder",
    #     "dir": "../results/vanilla",
    #     "exps": ["met_full", "met_full_10d"]},
    # "mt": {
    #     "type": "autoencoder",
    #     "dir": "../results/mt",
    #     "exps": ["e_0", "e_05", "e_2", "e_10", "e_100"]},
    # "10x": {
    #     "type": "autoencoder",
    #     "dir": "../results/10x",
    #     "exps": ["met_full", "met_weighted"]},
    # "ME": {
    #     "type": "autoencoder",
    #     "dir": "../results/ME",
    #     "exps": ["met_full"]}
    "sholl": {
        "type": "autoencoder",
        "dir": "../results/sholl",
        "exps": ["patchseq", "patchseq_M_weight", "met_full", "met_full_10d", "met_full_10d_ET", "met_patch_10d_ET", "met_MET_10d_ET",
                 "m_e", "e_m", "m_t", "t_m", "MET_M_weight"]
    }
}

# %%
all_experiments = {}
for (group, info) in all_exp_info.items():
    for exp_info in info["exps"]:
        (exp_dict, exp_name) = load_experiment(info["type"], info["dir"], exp_info)
        all_experiments.setdefault(group, {})[f"{exp_name}-{group}"] = exp_dict

# %% [markdown]
# ## Reconstructions

# %% [markdown]
# ### General Results

# %% [markdown]
# #### Setup

# %%
general_targets = {
    "patchseq": {
        "query": {"formats": [("logcpm", "pca-ipfx", "arbors")]},
        "modalities": ["T", "E", "M"],
        "loss": {
            "modalities": ["T", "E", "M"],
            "formats": {"T": ["logcpm"], "E": ["pca-ipfx"], "M": ["arbors"]},
            "losses": {"logcpm": "sample_r2", "pca-ipfx": "sample_r2", "arbors": "sample_r2"},
            "transform": {}},
        "groups": {"patch", "full", "grad", "complete", "smartseq", "cpl", "var", "tight", "loose", "direct", "decoupled", "ME", "fMOST"},
        "display": {"T": lambda x: 1 - x, "E": lambda x: 1 - x, "M": lambda x: 1 - x}
    },
    "EM": {
        "query": {"platforms": ["EM"]},
        "modalities": ["M"],
        "loss": {
            "formats": {"M": ["arbors"]},
            "losses": {"arbors": "sample_r2"},
            "transform": {}},
        "groups": {"patch", "full", "grad", "complete", "smartseq", "cpl", "var", "tight", "loose", "ME", "fMOST"},
        "display": {"M": lambda x: 1 - x}
    },
    "smartseq": {
        "query": {"platforms": ["smartseq"]},
        "modalities": ["T"],
        "loss": {
            "formats": {"T": ["logcpm"]},
            "losses": {"logcpm": "feature_r2"},
            "transform": {}},
        "groups": {"patch", "full", "grad", "complete", "smartseq", "cpl", "var", "tight", "loose"},
        "display": {"T": lambda x: 1 - x}
    },
    "10x": {
        "query": {"platforms": ["10x"]},
        "modalities": ["T"],
        "loss": {
            "formats": {"T": ["logcpm_trunc"]},
            "losses": {"logcpm_trunc": "feature_r2"},
            "transform": {}},
        "groups": {"10x"},
        "display": {"T": lambda x: 1 - x}
    },
    "sholl": {
        "query": {"formats": [("logcpm", "pca-ipfx", "arbors", "sholl")]},
        "modalities": ["T", "E", "M"],
        "loss": {
            "modalities": ["T", "E", "M"],
            "formats": {"T": ["logcpm"], "E": ["pca-ipfx"], "M": ["arbors", "sholl"]},
            "losses": {"logcpm": "sample_r2", "pca-ipfx": "sample_r2", "arbors": "sample_r2", "sholl": "sample_r2"},
            "transform": {}},
        "groups": {"patch", "full", "grad", "complete", "smartseq", "cpl", "var", "tight", "loose", "direct", "decoupled", "ME", "fMOST"},
        "display": {"T": lambda x: 1 - x, "E": lambda x: 1 - x, "M": lambda x: 1 - x}
    }
}

# %%
general_accs = {}

# %%
# specified = [("patchseq", "alignment", None), ("patchseq", "maxweight", None), ("patchseq", "weighted", None), ("patchseq", "vanilla", None), ("patchseq", "mt", None)]
specified = [("sholl", "sholl", None)]
plan = generate_recon_plan(specified, general_targets, all_experiments)
general_accs = run_recon_plan(plan, general_targets, met_data, all_experiments, general_accs)
general_scores = compute_scores(general_accs)
# Out:
# Running target sholl:
# Generating MET_M_weight-sholl - 10: M -> M
# Complete

# %%
general_columns = [("T->T", "sholl", "T->T"), ("E->E", "sholl", "E->E"), ("M->M", "sholl", "M->M"), 
                   ("E->T", "sholl", "E->T"), ("M->T", "sholl", "M->T"), ("T->E", "sholl", "T->E"), 
                   ("M->E", "sholl", "M->E"), ("T->M", "sholl", "T->M"), ("E->M", "sholl", "E->M")]
build_table(general_scores, general_columns, ["sholl"], 2, ["met_MET_10d_ET-sholl", "met_patch_10d_ET-sholl", "met_full_10d_ET-sholl"])
# Out:
#                              T->T       E->E       M->M       E->T       M->T  \
# met_MET_10d_ET-sholl     0.4±0.01  0.63±0.04  0.72±0.02  0.33±0.02  0.25±0.02
# met_patch_10d_ET-sholl  0.42±0.02  0.62±0.03  0.74±0.02  0.36±0.02  0.27±0.01
# met_full_10d_ET-sholl   0.41±0.02  0.64±0.03  0.64±0.03  0.37±0.01  0.25±0.02
#
#                              T->E       M->E       T->M       E->M
# met_MET_10d_ET-sholl    0.47±0.04   0.3±0.06  0.44±0.03   0.3±0.03
# met_patch_10d_ET-sholl  0.48±0.04  0.34±0.04  0.44±0.03  0.36±0.03
# met_full_10d_ET-sholl   0.48±0.04  0.24±0.05  0.44±0.03  0.39±0.03

# %%
general_columns = [("T->T", "sholl", "T->T"), ("E->E", "sholl", "E->E"), ("M->M", "sholl", "M->M"), 
                   ("E->T", "sholl", "E->T"), ("M->T", "sholl", "M->T"), ("T->E", "sholl", "T->E"), 
                   ("M->E", "sholl", "M->E"), ("T->M", "sholl", "T->M"), ("E->M", "sholl", "E->M")]
build_table(general_scores, general_columns, ["sholl"], 2, ["MET_M_weight-sholl", "patchseq_M_weight-sholl", "met_full-sholl",
                                                            "m_e-sholl", "e_m-sholl", "m_t-sholl", "t_m-sholl"])
# Out:
#                                T->T        E->E        M->M       E->T  \
# MET_M_weight-sholl        0.28±0.02   0.45±0.03   0.63±0.01  0.23±0.02
# patchseq_M_weight-sholl   0.35±0.02   0.47±0.03   0.63±0.03  0.26±0.02
# met_full-sholl            0.38±0.02   0.49±0.03   0.59±0.02  0.29±0.01
# m_e-sholl                        --  -0.57±0.32  -0.22±0.06         --
# e_m-sholl                        --  -0.05±0.05    -0.2±0.4         --
# m_t-sholl                -0.31±0.19          --  -0.22±0.06         --
# t_m-sholl                -1.84±0.02          --  -0.33±0.22         --
#
#                                M->T       T->E        M->E        T->M  \
# MET_M_weight-sholl         0.2±0.03  0.42±0.04   0.31±0.05   0.38±0.03
# patchseq_M_weight-sholl   0.22±0.02  0.45±0.04   0.31±0.04   0.39±0.03
# met_full-sholl            0.23±0.01  0.46±0.04   0.33±0.05   0.43±0.03
# m_e-sholl                        --         --   0.23±0.03          --
# e_m-sholl                        --         --  -0.06±0.04          --
# m_t-sholl                  0.2±0.02         --          --  -0.22±0.06
# t_m-sholl                -1.84±0.02         --          --    0.4±0.03
#
#                                E->M
# MET_M_weight-sholl        0.27±0.04
# patchseq_M_weight-sholl   0.28±0.03
# met_full-sholl            0.34±0.04
# m_e-sholl                -0.22±0.06
# e_m-sholl                 0.28±0.04
# m_t-sholl                        --
# t_m-sholl                        --

# %%
general_columns = [("T->T", "patchseq", "T->T"), ("E->E", "patchseq", "E->E"), ("M->M", "patchseq", "M->M"), 
                   ("E->T", "patchseq", "E->T"), ("M->T", "patchseq", "M->T"), ("T->E", "patchseq", "T->E"), 
                   ("M->E", "patchseq", "M->E"), ("T->M", "patchseq", "T->M"), ("E->M", "patchseq", "E->M")]
build_table(general_scores, general_columns, ["10x"], 2)
# Out:
#                        T->T       E->E       M->M       E->T       M->T  \
# met_full-10x      0.38±0.02  0.49±0.03  0.67±0.02   0.3±0.02  0.23±0.01
# met_weighted-10x  0.39±0.02   0.5±0.04  0.65±0.02  0.34±0.01  0.23±0.02
#
#                        T->E       M->E       T->M       E->M
# met_full-10x      0.46±0.03  0.31±0.04  0.39±0.02  0.24±0.04
# met_weighted-10x  0.47±0.04  0.29±0.05  0.37±0.03  0.27±0.04

# %%
general_columns = [("T->T", "patchseq", "T->T"), ("E->E", "patchseq", "E->E"), ("M->M", "patchseq", "M->M"), 
                   ("E->T", "patchseq", "E->T"), ("M->T", "patchseq", "M->T"), ("T->E", "patchseq", "T->E"), 
                   ("M->E", "patchseq", "M->E"), ("T->M", "patchseq", "T->M"), ("E->M", "patchseq", "E->M")]
build_table(general_scores, general_columns, ["ME", "weighted"], 2)
# Out:
#                                T->T       E->E       M->M       E->T  \
# met_full-ME               0.41±0.01   0.5±0.04  0.64±0.02  0.35±0.01
# met_et_2x-weighted         0.4±0.01  0.49±0.04  0.64±0.01  0.34±0.01
# met_et_4x-weighted         0.4±0.01   0.5±0.04  0.63±0.02  0.35±0.02
# met_et_4x_10d-weighted    0.44±0.01  0.75±0.03  0.73±0.01  0.37±0.01
# met_et_4x_MET-weighted    0.35±0.02  0.47±0.04  0.69±0.01   0.3±0.02
# met_et_4x_patch-weighted  0.39±0.01  0.49±0.04  0.72±0.01  0.34±0.01
#
#                                M->T       T->E       M->E       T->M  \
# met_full-ME               0.24±0.02  0.47±0.04  0.29±0.03  0.39±0.02
# met_et_2x-weighted        0.24±0.02  0.47±0.04  0.29±0.06  0.37±0.03
# met_et_4x-weighted        0.24±0.02  0.47±0.04   0.3±0.06  0.38±0.03
# met_et_4x_10d-weighted    0.24±0.03  0.49±0.04   0.19±0.1  0.39±0.02
# met_et_4x_MET-weighted    0.25±0.01  0.44±0.05  0.31±0.06  0.36±0.02
# met_et_4x_patch-weighted  0.25±0.02  0.46±0.04   0.3±0.07  0.35±0.03
#
#                                E->M
# met_full-ME               0.26±0.03
# met_et_2x-weighted        0.24±0.03
# met_et_4x-weighted        0.27±0.03
# met_et_4x_10d-weighted    0.26±0.04
# met_et_4x_MET-weighted    0.15±0.05
# met_et_4x_patch-weighted  0.19±0.04

# %%
general_columns = [("T->T", "patchseq", "T->T"), ("M->M", "patchseq", "M->M"),("T->M", "patchseq", "T->M"), ("M->T", "patchseq", "M->T")]
build_table(general_scores, general_columns, ["maxweight", "weighted", "alignment", "vanilla", "mt"], 2,
            ["e_0-mt", "e_05-mt", "met_full-alignment", "e_2-mt", "e_10-mt", "e_100-mt"])
# Out:
# Empty DataFrame
# Columns: [T->T, M->M, T->M, M->T]
# Index: []

# %%
general_columns = [("T->T", "patchseq", "T->T"), ("E->E", "patchseq", "E->E"), ("M->M", "patchseq", "M->M"), 
                   ("E->T", "patchseq", "E->T"), ("M->T", "patchseq", "M->T"), ("T->E", "patchseq", "T->E"), 
                   ("M->E", "patchseq", "M->E"), ("T->M", "patchseq", "T->M"), ("E->M", "patchseq", "E->M")]
build_table(general_scores, general_columns, ["maxweight", "weighted", "alignment", "vanilla"], 2,
            ["t_arm-maxweight", "e_arm-maxweight", "m_arm-maxweight", "e_t-maxweight", "m_t-maxweight", "t_e-maxweight",
             "m_e-maxweight", "t_m-maxweight", "e_m-maxweight", "met_full-alignment", "met_et_4x_MET-weighted",
             "met_et_4x_patch-weighted", "met_et_4x-weighted", "met_full-vanilla", "met_et_4x_10d-weighted", 
             "met_full_10d-vanilla"])
# Out:
#                                 T->T        E->E        M->M        E->T  \
# t_arm-maxweight            0.45±0.01          --          --          --
# e_arm-maxweight                   --   0.75±0.02          --          --
# m_arm-maxweight                   --          --   0.73±0.01          --
# e_t-maxweight             -0.28±0.18  -0.07±0.06          --   0.35±0.01
# m_t-maxweight             -0.21±0.26          --  -0.11±0.02          --
# t_e-maxweight              -1.9±0.02  -0.33±0.18          --  -1.89±0.02
# m_e-maxweight                     --  -0.29±0.28  -0.11±0.02          --
# t_m-maxweight             -1.89±0.02          --  -0.34±0.18          --
# e_m-maxweight                     --  -0.06±0.07  -0.27±0.19          --
# met_full-alignment          0.4±0.01   0.49±0.04   0.65±0.02   0.32±0.01
# met_et_4x_MET-weighted     0.35±0.02   0.46±0.04   0.69±0.01    0.3±0.02
# met_et_4x_patch-weighted   0.39±0.01   0.48±0.04   0.72±0.01   0.34±0.01
# met_et_4x-weighted          0.4±0.01   0.49±0.04   0.63±0.02   0.35±0.02
# met_full-vanilla           0.41±0.01    0.7±0.02   0.68±0.02   0.24±0.02
# met_et_4x_10d-weighted     0.44±0.01   0.75±0.03   0.74±0.01   0.37±0.01
# met_full_10d-vanilla       0.45±0.01   0.89±0.02   0.76±0.01    0.3±0.01
#
#                                 M->T        T->E        M->E        T->M  \
# t_arm-maxweight                   --          --          --          --
# e_arm-maxweight                   --          --          --          --
# m_arm-maxweight                   --          --          --          --
# e_t-maxweight                     --  -0.06±0.06          --          --
# m_t-maxweight              0.23±0.01          --          --  -0.11±0.02
# t_e-maxweight                     --   0.47±0.04          --          --
# m_e-maxweight                     --          --   0.23±0.07          --
# t_m-maxweight             -1.89±0.02          --          --   0.38±0.03
# e_m-maxweight                     --          --  -0.07±0.07          --
# met_full-alignment         0.25±0.01   0.46±0.04    0.3±0.05   0.38±0.02
# met_et_4x_MET-weighted     0.25±0.01   0.43±0.05    0.3±0.06   0.36±0.02
# met_et_4x_patch-weighted   0.25±0.02   0.46±0.04    0.3±0.07   0.35±0.03
# met_et_4x-weighted         0.24±0.02   0.47±0.04    0.3±0.06   0.38±0.03
# met_full-vanilla           0.23±0.01   0.47±0.04   0.28±0.05   0.38±0.03
# met_et_4x_10d-weighted     0.24±0.03   0.48±0.04    0.18±0.1   0.39±0.02
# met_full_10d-vanilla       0.25±0.01   0.49±0.04   0.29±0.05   0.41±0.02
#
#                                 E->M
# t_arm-maxweight                   --
# e_arm-maxweight                   --
# m_arm-maxweight                   --
# e_t-maxweight                     --
# m_t-maxweight                     --
# t_e-maxweight                     --
# m_e-maxweight             -0.11±0.02
# t_m-maxweight                     --
# e_m-maxweight              0.25±0.02
# met_full-alignment         0.22±0.04
# met_et_4x_MET-weighted     0.15±0.05
# met_et_4x_patch-weighted   0.19±0.04
# met_et_4x-weighted         0.27±0.03
# met_full-vanilla           0.17±0.03
# met_et_4x_10d-weighted     0.26±0.04
# met_full_10d-vanilla       0.23±0.02

# %%
general_columns = [("T->T", "patchseq", "T->T"), ("E->E", "patchseq", "E->E"), ("M->M", "patchseq", "M->M"), 
                   ("E->T", "patchseq", "E->T"), ("M->T", "patchseq", "M->T"), ("T->E", "patchseq", "T->E"), 
                   ("M->E", "patchseq", "M->E"), ("T->M", "patchseq", "T->M"), ("E->M", "patchseq", "E->M")]
build_table(general_scores, general_columns, ["10x"], 2)
# Out:
#                    T->T       E->E       M->M      E->T       M->T       T->E  \
# met_full-10x  0.38±0.02  0.49±0.03  0.67±0.02  0.3±0.02  0.23±0.01  0.46±0.03
#
#                    M->E       T->M       E->M
# met_full-10x  0.31±0.04  0.39±0.02  0.24±0.04

# %%
general_columns = [("T->T", "patchseq", "T->T"), ("E->T", "patchseq", "E->T"), ("M->T", "patchseq", "M->T"), ("T->T", "smartseq", "T->T (Aligned)"), 
           ("E->E", "patchseq", "E->E"), ("T->E", "patchseq", "T->E"), ("M->E", "patchseq", "M->E"), ("M->M", "patchseq", "M->M"), 
           ("T->M", "patchseq", "T->M"), ("E->M", "patchseq", "E->M")]
build_table(general_scores, general_columns, ["alignment"], 2)
# Out:
#                            T->T       E->T       M->T T->T (Aligned)  \
# t_patchseq-alignment  0.46±0.01         --         --       0.3±0.01
# t_both-alignment      0.46±0.01         --         --       0.46±0.0
# met_patch-alignment    0.4±0.01  0.31±0.02  0.26±0.01      0.23±0.01
# met_both-alignment     0.4±0.01  0.31±0.01  0.26±0.01      0.34±0.02
# met_full-alignment     0.4±0.01  0.32±0.01  0.25±0.01      0.35±0.01
#
#                            E->E       T->E       M->E       M->M       T->M  \
# t_patchseq-alignment         --         --         --         --         --
# t_both-alignment             --         --         --         --         --
# met_patch-alignment   0.48±0.04  0.46±0.04   0.3±0.05  0.73±0.01  0.35±0.02
# met_both-alignment    0.48±0.04  0.46±0.04  0.31±0.06  0.74±0.02  0.36±0.03
# met_full-alignment    0.49±0.04  0.46±0.04   0.3±0.05  0.65±0.02  0.38±0.02
#
#                            E->M
# t_patchseq-alignment         --
# t_both-alignment             --
# met_patch-alignment   0.15±0.04
# met_both-alignment    0.18±0.03
# met_full-alignment    0.22±0.04

# %%
general_columns = [("T->T", "patchseq", "T->T"), ("E->T", "patchseq", "E->T"), ("M->T", "patchseq", "M->T"), ("T->T", "smartseq", "T->T (Unaligned)"), 
           ("E->E", "patchseq", "E->E"), ("T->E", "patchseq", "T->E"), ("M->E", "patchseq", "M->E"), ("M->M", "patchseq", "M->M"), 
           ("T->M", "patchseq", "T->M"), ("E->M", "patchseq", "E->M")]
build_table(general_scores, general_columns, ["alignment"], 2)
# Out:
#                            T->T       E->T       M->T T->T (Unaligned)  \
# t_patchseq-alignment  0.46±0.01         --         --        0.05±0.01
# t_both-alignment      0.46±0.01         --         --         0.14±0.0
# met_patch-alignment    0.4±0.01  0.31±0.02  0.26±0.01        -0.1±0.01
# met_both-alignment     0.4±0.01  0.31±0.01  0.26±0.01        0.07±0.02
#
#                            E->E       T->E       M->E       M->M       T->M  \
# t_patchseq-alignment         --         --         --         --         --
# t_both-alignment             --         --         --         --         --
# met_patch-alignment   0.48±0.04  0.46±0.04   0.3±0.05  0.73±0.01  0.35±0.02
# met_both-alignment    0.48±0.04  0.46±0.04  0.31±0.06  0.74±0.02  0.36±0.03
#
#                            E->M
# t_patchseq-alignment         --
# t_both-alignment             --
# met_patch-alignment   0.15±0.04
# met_both-alignment    0.18±0.03

# %%
general_columns = [("T->T", "patchseq", "T->T"), ("E->T", "patchseq", "E->T"), ("M->T", "patchseq", "M->T"), 
           ("E->E", "patchseq", "E->E"), ("T->E", "patchseq", "T->E"), ("M->E", "patchseq", "M->E"), ("M->M", "patchseq", "M->M"), 
           ("T->M", "patchseq", "T->M"), ("E->M", "patchseq", "E->M")]
build_table(general_scores, general_columns, ["simple"], 2)
# Out:
#                            T->T       E->T       M->T       E->E       T->E  \
# coupled-simple        0.29±0.05  0.23±0.04  0.11±0.04  0.55±0.06  0.43±0.04
# cross-simple          0.42±0.01  0.25±0.02  0.24±0.01   0.7±0.03  0.48±0.04
# cross_coupled-simple  0.31±0.06  0.26±0.06  0.17±0.02  0.54±0.08  0.46±0.05
#
#                            M->E       M->M       T->M       E->M
# coupled-simple        0.09±0.17  0.39±0.05  0.15±0.09  0.02±0.08
# cross-simple          0.29±0.05  0.72±0.01  0.39±0.03  0.16±0.03
# cross_coupled-simple  0.24±0.05  0.36±0.04  0.32±0.03  0.22±0.03

# %% [markdown]
# #### R2 Table

# %%
general_columns = [("T->T", "patchseq", "T->T"), ("E->T", "patchseq", "E->T"), ("M->T", "patchseq", "M->T"), ("T->T", "smartseq", "T->T (Tasic)"), 
           ("E->E", "patchseq", "E->E"), ("T->E", "patchseq", "T->E"), ("M->E", "patchseq", "M->E"), ("M->M", "patchseq", "M->M"), 
           ("T->M", "patchseq", "T->M"), ("E->M", "patchseq", "E->M"), ("M->M", "EM", "M->M (EM)")]
build_table(general_scores, general_columns, ["cca", "patch", "full", "complete"], 2)
# Out:
#                         T->T       E->T       M->T T->T (Tasic)       E->E  \
# t_e_cca-cca        0.16±0.02  0.14±0.02         --    -0.29±0.0  0.26±0.07
# t_m_cca-cca        0.15±0.01         --  0.14±0.02    -0.31±0.0         --
# e_m_cca-cca               --         --         --           --   0.2±0.07
# t_arm-patch        0.37±0.01         --         --    0.03±0.01         --
# e_arm-patch               --         --         --           --  0.55±0.04
# m_arm-patch               --         --         --           --         --
# t_e_arms-patch     0.34±0.01  0.27±0.01         --   -0.07±0.01  0.52±0.04
# t_m_arms-patch     0.24±0.05         --  0.16±0.04   -0.17±0.04         --
# e_m_arms-patch            --         --         --           --  0.34±0.06
# met-patch          0.24±0.02   0.2±0.02  0.13±0.02   -0.16±0.02  0.34±0.06
# m_arm-full                --         --         --           --         --
# t_m_arms-full      0.28±0.02         --  0.17±0.02   -0.12±0.02         --
# e_m_arms-full             --         --         --           --  0.36±0.06
# met-full           0.28±0.03  0.23±0.03  0.14±0.02   -0.13±0.02  0.34±0.06
# t_m_arms-complete  0.26±0.02         --  0.17±0.02     0.4±0.03         --
# met-complete       0.29±0.02  0.24±0.03  0.13±0.02     0.4±0.04  0.35±0.05
#
#                         T->E       M->E       M->M       T->M       E->M  \
# t_e_cca-cca        0.23±0.07         --         --         --         --
# t_m_cca-cca               --         --  0.24±0.03  0.22±0.03         --
# e_m_cca-cca               --  0.14±0.08  0.22±0.03         --  0.13±0.04
# t_arm-patch               --         --         --         --         --
# e_arm-patch               --         --         --         --         --
# m_arm-patch               --         --  0.71±0.02         --         --
# t_e_arms-patch     0.33±0.07         --         --         --         --
# t_m_arms-patch            --         --  0.62±0.04  0.28±0.06         --
# e_m_arms-patch            --   0.1±0.11  0.51±0.04         --   0.09±0.1
# met-patch          0.31±0.07  0.16±0.08  0.37±0.05   0.3±0.04  0.22±0.04
# m_arm-full                --         --  0.71±0.03         --         --
# t_m_arms-full             --         --  0.54±0.04  0.31±0.04         --
# e_m_arms-full             --  0.12±0.08  0.44±0.04         --  0.19±0.04
# met-full           0.31±0.06  0.11±0.08   0.4±0.03  0.31±0.03  0.24±0.04
# t_m_arms-complete         --         --  0.55±0.05  0.31±0.05         --
# met-complete       0.31±0.06  0.12±0.09  0.39±0.04   0.3±0.04  0.23±0.05
#
#                    M->M (EM)
# t_e_cca-cca               --
# t_m_cca-cca         0.11±0.0
# e_m_cca-cca        0.03±0.02
# t_arm-patch               --
# e_arm-patch               --
# m_arm-patch        0.63±0.03
# t_e_arms-patch            --
# t_m_arms-patch     0.53±0.05
# e_m_arms-patch     0.35±0.07
# met-patch          0.24±0.05
# m_arm-full          0.79±0.0
# t_m_arms-full      0.69±0.01
# e_m_arms-full      0.66±0.01
# met-full           0.62±0.03
# t_m_arms-complete  0.71±0.03
# met-complete       0.62±0.06

# %% [markdown]
# #### Summary Tables

# %%
build_table(general_scores, [
    ("T->T", "patchseq", "T->T"), ("E->T", "patchseq", "E->T"), ("M->T", "patchseq", "M->T"), ("E->E", "patchseq", "E->E"), 
    ("T->E", "patchseq", "T->E"), ("M->E", "patchseq", "M->E"), ("M->M", "patchseq", "M->M"), ("T->M", "patchseq", "T->M"), 
    ("E->M", "patchseq", "E->M")],
            ["multiscale"], 2)
# Out:
#                                T->T       E->T       M->T       E->E  \
# 120_4_4_patch-multiscale  0.37±0.01  0.29±0.01  0.23±0.01  0.48±0.05
# 120_4_4_EM-multiscale     0.38±0.01  0.29±0.02  0.22±0.02  0.49±0.05
#
#                                T->E       M->E       M->M       T->M  \
# 120_4_4_patch-multiscale  0.45±0.05  0.31±0.05  0.68±0.02  0.29±0.04
# 120_4_4_EM-multiscale     0.46±0.04  0.29±0.05   0.6±0.03  0.32±0.04
#
#                                E->M
# 120_4_4_patch-multiscale  0.11±0.04
# 120_4_4_EM-multiscale     0.17±0.05

# %%
build_table(general_scores, [
    ("T->T", "patchseq", "T->T"), ("E->T", "patchseq", "E->T"), ("M->T", "patchseq", "M->T"), ("E->E", "patchseq", "E->E"), 
    ("T->E", "patchseq", "T->E"), ("M->E", "patchseq", "M->E"), ("M->M", "patchseq", "M->M"), ("T->M", "patchseq", "T->M"), 
    ("E->M", "patchseq", "E->M")],
            ["baseline"], 2, ["t_arm-baseline", "e_arm-baseline", "m_arm-baseline", "t_e_arms-baseline", "t_m_arms-baseline", "e_m_arms-baseline",
                              "met-baseline"])
# Out:
#                         T->T       E->T       M->T       E->E       T->E  \
# t_arm-baseline     0.43±0.02         --         --         --         --
# e_arm-baseline            --         --         --  0.75±0.02         --
# m_arm-baseline            --         --         --         --         --
# t_e_arms-baseline  0.42±0.02  0.32±0.02         --   0.6±0.03  0.48±0.04
# t_m_arms-baseline  0.38±0.01         --  0.22±0.02         --         --
# e_m_arms-baseline         --         --         --  0.44±0.04         --
# met-baseline       0.38±0.01  0.29±0.02  0.23±0.01  0.48±0.04  0.46±0.04
#
#                         M->E       M->M       T->M       E->M
# t_arm-baseline            --         --         --         --
# e_arm-baseline            --         --         --         --
# m_arm-baseline            --  0.74±0.01         --         --
# t_e_arms-baseline         --         --         --         --
# t_m_arms-baseline         --  0.74±0.01  0.32±0.05         --
# e_m_arms-baseline  0.26±0.05  0.75±0.02         --  0.12±0.05
# met-baseline       0.28±0.06  0.73±0.01  0.34±0.03  0.16±0.04

# %%
build_table(general_scores, [
    ("T->T", "patchseq", "T->T"), ("E->T", "patchseq", "E->T"), ("M->T", "patchseq", "M->T"), ("E->E", "patchseq", "E->E"), 
    ("T->E", "patchseq", "T->E"), ("M->E", "patchseq", "M->E"), ("M->M", "patchseq", "M->M"), ("T->M", "patchseq", "T->M"), 
    ("E->M", "patchseq", "E->M")],
            ["mmvae"], 2)
# Out:
#                   T->T       E->T       M->T       E->E       T->E       M->E  \
# met-mmvae    0.44±0.01  0.33±0.01  0.25±0.01   0.8±0.02  0.47±0.04  0.29±0.07
# met_0-mmvae  0.43±0.01  0.34±0.01  0.25±0.02  0.76±0.02  0.48±0.04  0.22±0.08
#
#                   M->M       T->M       E->M
# met-mmvae    0.77±0.01  0.37±0.03  0.18±0.04
# met_0-mmvae  0.76±0.01  0.39±0.03  0.18±0.03

# %%
build_table(general_scores, [
    ("T->T", "patchseq", "T->T"), ("E->T", "patchseq", "E->T"), ("M->T", "patchseq", "M->T"), ("E->E", "patchseq", "E->E"), 
    ("T->E", "patchseq", "T->E"), ("M->E", "patchseq", "M->E"), ("M->M", "patchseq", "M->M"), ("T->M", "patchseq", "T->M"), 
    ("E->M", "patchseq", "E->M")],
            ["baseline"], 2, ["t_arm-baseline", "e_arm-baseline", "t_e_arms-baseline", "met-baseline"])
# Out:
#                         T->T       E->T       M->T       E->E       T->E  \
# t_arm-baseline     0.43±0.02         --         --         --         --
# e_arm-baseline            --         --         --  0.75±0.02         --
# t_e_arms-baseline  0.42±0.02  0.32±0.02         --   0.6±0.03  0.48±0.04
# met-baseline       0.38±0.01  0.29±0.02  0.23±0.01  0.48±0.04  0.46±0.04
#
#                         M->E       M->M       T->M       E->M
# t_arm-baseline            --         --         --         --
# e_arm-baseline            --         --         --         --
# t_e_arms-baseline         --         --         --         --
# met-baseline       0.28±0.06  0.73±0.01  0.34±0.03  0.16±0.04

# %%
build_table({"patchseq": {**ivscc_scores["ivscc-patchseq"], **hist_scores["patchseq"]}}, [
    ("T->T", "patchseq", "T->T"), ("E->T", "patchseq", "E->T"), ("M->T", "patchseq", "M->T"), ("E->E", "patchseq", "E->E"), 
    ("T->E", "patchseq", "T->E"), ("M->E", "patchseq", "M->E"), ("M->M", "patchseq", "M->M"), ("T->M", "patchseq", "T->M"), 
    ("E->M", "patchseq", "E->M")],
            ["ivscc", "densities"], 2)
# Out:
#                              T->T       E->T       M->T       E->E       T->E  \
# met-ivscc                0.4±0.01  0.31±0.02  0.28±0.02  0.55±0.04  0.47±0.06
# 120_1_4-densities       0.38±0.02  0.28±0.01  0.23±0.01  0.47±0.04  0.45±0.05
# 120_4_4-densities       0.38±0.01  0.28±0.01  0.23±0.01  0.47±0.04  0.45±0.04
# 120_8_4-densities       0.38±0.01  0.28±0.02  0.24±0.01  0.48±0.04  0.45±0.05
# 120_16_4-densities      0.37±0.01  0.29±0.02  0.22±0.02  0.49±0.04  0.46±0.05
# 120_32_4-densities      0.37±0.02  0.29±0.02  0.22±0.02   0.5±0.04  0.46±0.04
# 120_64_4-densities      0.38±0.01   0.3±0.02  0.22±0.02  0.52±0.03  0.45±0.05
# 120_120_4-densities     0.39±0.02  0.31±0.02  0.21±0.02  0.53±0.04  0.46±0.04
# 5_4_4-densities         0.34±0.02  0.22±0.03  0.22±0.02  0.37±0.05  0.41±0.05
# 10_4_4-densities        0.36±0.01  0.22±0.03  0.22±0.01  0.39±0.05  0.43±0.04
# 25_4_4-densities        0.35±0.03  0.24±0.03  0.22±0.02  0.41±0.05  0.43±0.05
# 50_4_4-densities        0.36±0.02  0.26±0.02  0.22±0.02  0.44±0.04  0.44±0.05
# 200_4_4-densities       0.39±0.01   0.3±0.02  0.22±0.01  0.49±0.04  0.46±0.04
# 120_4_1-densities       0.37±0.02  0.27±0.03  0.13±0.02  0.45±0.05  0.45±0.04
# 1_1_4-densities         0.39±0.03  0.31±0.02  0.12±0.01  0.56±0.06  0.46±0.05
# 120_4_4_100-densities   0.37±0.02  0.29±0.02   0.2±0.02  0.49±0.04  0.45±0.04
# 120_4_4_500-densities   0.37±0.01  0.28±0.02  0.23±0.02  0.48±0.05  0.45±0.04
# 120_4_4_2000-densities  0.38±0.02  0.28±0.02  0.22±0.02  0.48±0.05  0.45±0.05
# 120_32_4_100-densities  0.37±0.02   0.3±0.02  0.18±0.02  0.54±0.04  0.45±0.04
# 120_32_4_250-densities  0.37±0.01   0.3±0.01  0.21±0.02  0.53±0.03  0.45±0.04
# 120_32_4_500-densities  0.37±0.02   0.3±0.02  0.21±0.02  0.52±0.04  0.45±0.05
#
#                              M->E       M->M       T->M        E->M
# met-ivscc               0.36±0.06  0.53±0.02  0.36±0.04   0.28±0.05
# 120_1_4-densities       0.28±0.06  0.73±0.01  0.35±0.04   0.14±0.03
# 120_4_4-densities       0.29±0.06  0.73±0.01  0.34±0.04   0.14±0.04
# 120_8_4-densities        0.3±0.05  0.71±0.01  0.31±0.04    0.1±0.05
# 120_16_4-densities      0.29±0.06  0.62±0.02  0.24±0.04   0.08±0.04
# 120_32_4-densities      0.29±0.06   0.5±0.02  0.15±0.04   0.01±0.06
# 120_64_4-densities      0.28±0.05  0.35±0.03   0.1±0.03   0.02±0.04
# 120_120_4-densities     0.26±0.05  0.21±0.03  0.06±0.04   -0.0±0.03
# 5_4_4-densities         0.27±0.05  0.96±0.01  0.61±0.04   0.35±0.05
# 10_4_4-densities        0.27±0.05  0.92±0.01  0.49±0.04   0.23±0.06
# 25_4_4-densities        0.29±0.04  0.84±0.03   0.4±0.03   0.16±0.04
# 50_4_4-densities        0.28±0.05  0.79±0.02  0.36±0.03   0.14±0.05
# 200_4_4-densities       0.27±0.05  0.69±0.01  0.33±0.03   0.15±0.04
# 120_4_1-densities       0.17±0.06  0.79±0.01  0.37±0.04   0.13±0.06
# 1_1_4-densities         0.19±0.06  0.75±0.33  0.75±0.33   0.75±0.33
# 120_4_4_100-densities   0.24±0.06  0.45±0.03  0.12±0.05   0.02±0.05
# 120_4_4_500-densities   0.28±0.06   0.7±0.01  0.31±0.03   0.12±0.04
# 120_4_4_2000-densities  0.28±0.06  0.73±0.02  0.34±0.03   0.16±0.04
# 120_32_4_100-densities  0.23±0.06   0.1±0.05  0.02±0.06  -0.01±0.06
# 120_32_4_250-densities  0.27±0.04  0.21±0.04  0.06±0.04   0.01±0.04
# 120_32_4_500-densities  0.27±0.05  0.35±0.02   0.1±0.04   0.02±0.04

# %%
build_table(general_scores, [
    ("T->T", "patchseq", "T->T"), ("E->T", "patchseq", "E->T"), ("M->T", "patchseq", "M->T"), ("E->E", "patchseq", "E->E"), 
    ("T->E", "patchseq", "T->E"), ("M->E", "patchseq", "M->E"), ("M->M", "patchseq", "M->M"), ("T->M", "patchseq", "T->M"), 
    ("E->M", "patchseq", "E->M")], ["baseline", "hist"], 2, ["120_4_4_MET-hist", "met-baseline", "120_4_4_EM-hist", "met_full-baseline"])
# Out:
#                         T->T       E->T       M->T       E->E       T->E  \
# 120_4_4_MET-hist   0.33±0.03  0.24±0.02  0.19±0.01  0.44±0.05  0.43±0.05
# met-baseline       0.38±0.01  0.29±0.02  0.23±0.01  0.48±0.04  0.46±0.04
# 120_4_4_EM-hist    0.38±0.01   0.3±0.02  0.22±0.02  0.48±0.04  0.46±0.04
# met_full-baseline  0.36±0.01  0.28±0.01  0.21±0.02  0.47±0.02  0.44±0.03
#
#                         M->E       M->M       T->M       E->M
# 120_4_4_MET-hist   0.26±0.06  0.71±0.01  0.34±0.02  0.09±0.03
# met-baseline       0.28±0.06  0.73±0.01  0.34±0.03  0.16±0.04
# 120_4_4_EM-hist    0.28±0.06  0.65±0.02  0.37±0.03  0.22±0.03
# met_full-baseline  0.27±0.04  0.65±0.02  0.38±0.02  0.24±0.03

# %%
build_table(general_scores, [
    ("E->T", "patchseq", "E->T"), ("M->T", "patchseq", "M->T"), ("T->E", "patchseq", "T->E"), ("M->E", "patchseq", "M->E"), 
    ("T->M", "patchseq", "T->M"), ("E->M", "patchseq", "E->M")], ["e2e"], 2)
# Out:
#                E->T        M->T        T->E        M->E        T->M  \
# t_e-e2e  -1.86±0.02          --   0.49±0.04          --          --
# e_t-e2e   0.36±0.02          --  -0.05±0.06          --          --
# m_e-e2e          --          --          --   0.22±0.06          --
# e_m-e2e          --          --          --  -0.07±0.07          --
# t_m-e2e          --  -1.85±0.02          --          --   0.39±0.02
# m_t-e2e          --   0.22±0.01          --          --  -0.12±0.02
#
#                E->M
# t_e-e2e          --
# e_t-e2e          --
# m_e-e2e  -0.12±0.02
# e_m-e2e   0.27±0.02
# t_m-e2e          --
# m_t-e2e          --

# %%
build_table(general_scores, [("M->T", "patchseq", "M->T"), ("M->E", "patchseq", "M->E"), 
    ("T->M", "patchseq", "T->M"), ("E->M", "patchseq", "E->M")], ["baseline", "tree", "e2e"], 2, ["met_full-baseline", "e_m-e2e", "m_e-e2e", "t_m-e2e", "m_t-e2e", "raw_0-tree"])
# Out:
#                          M->T        M->E        T->M        E->M
# met_full-baseline   0.21±0.02   0.28±0.05   0.38±0.03   0.23±0.03
# e_m-e2e                    --  -0.07±0.07          --   0.27±0.02
# m_e-e2e                    --   0.22±0.06          --  -0.12±0.02
# t_m-e2e            -1.85±0.02          --   0.39±0.02          --
# m_t-e2e             0.22±0.01          --  -0.12±0.02          --
# raw_0-tree          0.24±0.02   0.23±0.05   0.38±0.03   0.24±0.03

# %%
build_table(general_scores, [
    ("T->T", "patchseq", "T->T"), ("E->T", "patchseq", "E->T"), ("M->T", "patchseq", "M->T"), ("E->E", "patchseq", "E->E"), 
    ("T->E", "patchseq", "T->E"), ("M->E", "patchseq", "M->E"), ("M->M", "patchseq", "M->M"), ("T->M", "patchseq", "T->M"), 
    ("E->M", "patchseq", "E->M")],
            ["tree"], 2)
# Out:
#                    T->T       E->T       M->T       E->E       T->E  \
# raw_0-tree    0.42±0.01  0.33±0.01  0.24±0.02  0.47±0.04  0.46±0.03
# raw_10-tree   0.42±0.01  0.33±0.01  0.24±0.02  0.47±0.03  0.46±0.03
# raw_20-tree   0.42±0.01  0.34±0.01  0.24±0.02  0.47±0.03  0.46±0.03
# raw_30-tree   0.41±0.01  0.34±0.01  0.24±0.02  0.46±0.04  0.46±0.03
# raw_40-tree   0.41±0.01  0.34±0.02  0.24±0.02  0.46±0.03  0.45±0.03
# raw_50-tree    0.4±0.01  0.33±0.02  0.25±0.02  0.45±0.03  0.45±0.03
# raw_60-tree    0.4±0.01  0.34±0.02  0.25±0.02  0.45±0.03  0.44±0.02
# raw_70-tree    0.4±0.01  0.34±0.02  0.25±0.02  0.44±0.03  0.44±0.03
# raw_80-tree   0.39±0.01  0.33±0.02  0.25±0.01  0.44±0.03  0.43±0.03
# raw_90-tree   0.33±0.01  0.29±0.01  0.24±0.02  0.39±0.04  0.39±0.03
# raw_100-tree  0.19±0.01  0.18±0.01  0.18±0.01  0.22±0.05  0.21±0.05
#
#                    M->E       M->M       T->M       E->M
# raw_0-tree    0.23±0.05  0.48±0.02  0.38±0.03  0.24±0.03
# raw_10-tree   0.24±0.05  0.46±0.03  0.37±0.03  0.26±0.03
# raw_20-tree   0.23±0.04  0.45±0.03  0.37±0.03  0.26±0.03
# raw_30-tree   0.23±0.04  0.44±0.03  0.37±0.03  0.26±0.03
# raw_40-tree   0.23±0.04  0.42±0.03  0.36±0.03  0.26±0.03
# raw_50-tree   0.25±0.05  0.41±0.03  0.36±0.03  0.26±0.03
# raw_60-tree   0.25±0.04  0.38±0.03  0.34±0.03  0.26±0.03
# raw_70-tree   0.24±0.06  0.38±0.03  0.34±0.03  0.26±0.04
# raw_80-tree   0.25±0.05  0.37±0.03  0.34±0.03  0.27±0.02
# raw_90-tree   0.25±0.05  0.26±0.03  0.24±0.03   0.2±0.03
# raw_100-tree  0.19±0.05  0.14±0.03  0.13±0.03  0.13±0.03

# %%
build_table(general_scores, [
    ("T->T", "patchseq", "T->T"), ("E->T", "patchseq", "E->T"), ("M->T", "patchseq", "M->T"), ("E->E", "patchseq", "E->E"), 
    ("T->E", "patchseq", "T->E"), ("M->E", "patchseq", "M->E"), ("M->M", "patchseq", "M->M"), ("T->M", "patchseq", "T->M"), 
    ("E->M", "patchseq", "E->M")],
            ["baseline", "recon", "elbo"], 2, ["met-baseline", "met_nocpl-baseline", "cross-recon", "coupled-recon", "met-elbo"])
# Out:
#                          T->T       E->T       M->T       E->E       T->E  \
# met-baseline        0.38±0.01  0.29±0.02  0.23±0.01  0.48±0.04  0.46±0.04
# met_nocpl-baseline  0.38±0.02  0.28±0.02  0.22±0.01  0.48±0.04  0.45±0.05
# cross-recon         0.42±0.01  0.24±0.02  0.24±0.01   0.7±0.03  0.47±0.05
# coupled-recon       0.29±0.05  0.22±0.04   0.1±0.04  0.54±0.06  0.42±0.04
# met-elbo            0.35±0.04  0.27±0.02  0.15±0.03  0.45±0.05  0.43±0.04
#
#                          M->E       M->M       T->M       E->M
# met-baseline        0.28±0.06  0.73±0.01  0.34±0.03  0.16±0.04
# met_nocpl-baseline  0.28±0.06  0.73±0.01  0.34±0.03  0.15±0.06
# cross-recon         0.28±0.05  0.72±0.01  0.39±0.03  0.17±0.03
# coupled-recon       0.07±0.17  0.39±0.05  0.15±0.09  0.02±0.08
# met-elbo            0.23±0.06   0.7±0.01  0.17±0.05  0.01±0.05

# %%
def bold_stuff(value):
    bold = 'bold' if value in {"0.37±0.03", "0.22±0.03"} else ''
    return f'font-weight: {bold}'

build_table(general_scores, [
    ("T->T", "patchseq", "T->T"), ("E->T", "patchseq", "E->T"), ("M->T", "patchseq", "M->T"), ("E->E", "patchseq", "E->E"), 
    ("T->E", "patchseq", "T->E"), ("M->E", "patchseq", "M->E"), ("M->M", "patchseq", "M->M"), ("T->M", "patchseq", "T->M"), 
    ("E->M", "patchseq", "E->M")],
            ["baseline", "hist"], 2, ["120_4_4_MET-hist", "met-baseline", "120_4_4_EM-hist"], bold_stuff)
# Out:
# <style type="text/css">
# #T_1c113_row0_col0, #T_1c113_row0_col1, #T_1c113_row0_col2, #T_1c113_row0_col3, #T_1c113_row0_col4, #T_1c113_row0_col5, #T_1c113_row0_col6, #T_1c113_row0_col7, #T_1c113_row0_col8, #T_1c113_row1_col0, #T_1c113_row1_col1, #T_1c113_row1_col2, #T_1c113_row1_col3, #T_1c113_row1_col4, #T_1c113_row1_col5, #T_1c113_row1_col6, #T_1c113_row1_col7, #T_1c113_row1_col8, #T_1c113_row2_col0, #T_1c113_row2_col1, #T_1c113_row2_col2, #T_1c113_row2_col3, #T_1c113_row2_col4, #T_1c113_row2_col5, #T_1c113_row2_col6 {
#   font-weight: ;
# }
# #T_1c113_row2_col7, #T_1c113_row2_col8 {
#   font-weight: bold;
# }
# </style>
# <table id="T_1c113">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1c113_level0_col0" class="col_heading level0 col0" >T->T</th>
#       <th id="T_1c113_level0_col1" class="col_heading level0 col1" >E->T</th>
#       <th id="T_1c113_level0_col2" class="col_heading level0 col2" >M->T</th>
#       <th id="T_1c113_level0_col3" class="col_heading level0 col3" >E->E</th>
#       <th id="T_1c113_level0_col4" class="col_heading level0 col4" >T->E</th>
#       <th id="T_1c113_level0_col5" class="col_heading level0 col5" >M->E</th>
#       <th id="T_1c113_level0_col6" class="col_heading level0 col6" >M->M</th>
#       <th id="T_1c113_level0_col7" class="col_heading level0 col7" >T->M</th>
#       <th id="T_1c113_level0_col8" class="col_heading level0 col8" >E->M</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1c113_level0_row0" class="row_heading level0 row0" >120_4_4_MET-hist</th>
#       <td id="T_1c113_row0_col0" class="data row0 col0" >0.33±0.03</td>
#       <td id="T_1c113_row0_col1" class="data row0 col1" >0.24±0.02</td>
#       <td id="T_1c113_row0_col2" class="data row0 col2" >0.19±0.01</td>
#       <td id="T_1c113_row0_col3" class="data row0 col3" >0.44±0.05</td>
#       <td id="T_1c113_row0_col4" class="data row0 col4" >0.43±0.05</td>
#       <td id="T_1c113_row0_col5" class="data row0 col5" >0.26±0.06</td>
#       <td id="T_1c113_row0_col6" class="data row0 col6" >0.71±0.01</td>
#       <td id="T_1c113_row0_col7" class="data row0 col7" >0.34±0.02</td>
#       <td id="T_1c113_row0_col8" class="data row0 col8" >0.09±0.03</td>
#     </tr>
#     <tr>
#       <th id="T_1c113_level0_row1" class="row_heading level0 row1" >met-baseline</th>
#       <td id="T_1c113_row1_col0" class="data row1 col0" >0.38±0.01</td>
#       <td id="T_1c113_row1_col1" class="data row1 col1" >0.29±0.02</td>
#       <td id="T_1c113_row1_col2" class="data row1 col2" >0.23±0.01</td>
#       <td id="T_1c113_row1_col3" class="data row1 col3" >0.48±0.04</td>
#       <td id="T_1c113_row1_col4" class="data row1 col4" >0.46±0.04</td>
#       <td id="T_1c113_row1_col5" class="data row1 col5" >0.28±0.06</td>
#       <td id="T_1c113_row1_col6" class="data row1 col6" >0.73±0.01</td>
#       <td id="T_1c113_row1_col7" class="data row1 col7" >0.34±0.03</td>
#       <td id="T_1c113_row1_col8" class="data row1 col8" >0.16±0.04</td>
#     </tr>
#     <tr>
#       <th id="T_1c113_level0_row2" class="row_heading level0 row2" >120_4_4_EM-hist</th>
#       <td id="T_1c113_row2_col0" class="data row2 col0" >0.38±0.01</td>
#       <td id="T_1c113_row2_col1" class="data row2 col1" >0.3±0.02</td>
#       <td id="T_1c113_row2_col2" class="data row2 col2" >0.22±0.02</td>
#       <td id="T_1c113_row2_col3" class="data row2 col3" >0.48±0.04</td>
#       <td id="T_1c113_row2_col4" class="data row2 col4" >0.46±0.04</td>
#       <td id="T_1c113_row2_col5" class="data row2 col5" >0.28±0.06</td>
#       <td id="T_1c113_row2_col6" class="data row2 col6" >0.65±0.02</td>
#       <td id="T_1c113_row2_col7" class="data row2 col7" >0.37±0.03</td>
#       <td id="T_1c113_row2_col8" class="data row2 col8" >0.22±0.03</td>
#     </tr>
#   </tbody>
# </table>

# %%
def bold_stuff(value):
    bold = 'bold' if value in {"0.37±0.03", "0.22±0.03"} else ''
    return f'font-weight: {bold}'

build_table(general_scores, [
    ("T->T", "patchseq", "T->T"), ("E->T", "patchseq", "E->T"), ("M->T", "patchseq", "M->T"), ("E->E", "patchseq", "E->E"), 
    ("T->E", "patchseq", "T->E"), ("M->E", "patchseq", "M->E"), ("M->M", "patchseq", "M->M"), ("T->M", "patchseq", "T->M"), 
    ("E->M", "patchseq", "E->M")],
            ["hist", "e2e"], 2, style_map = bold_stuff)
# Out:
# <style type="text/css">
# #T_f9f2a_row0_col0, #T_f9f2a_row0_col1, #T_f9f2a_row0_col2, #T_f9f2a_row0_col3, #T_f9f2a_row0_col4, #T_f9f2a_row0_col5, #T_f9f2a_row0_col6, #T_f9f2a_row0_col7, #T_f9f2a_row0_col8, #T_f9f2a_row1_col0, #T_f9f2a_row1_col1, #T_f9f2a_row1_col2, #T_f9f2a_row1_col3, #T_f9f2a_row1_col4, #T_f9f2a_row1_col5, #T_f9f2a_row1_col6, #T_f9f2a_row2_col0, #T_f9f2a_row2_col1, #T_f9f2a_row2_col2, #T_f9f2a_row2_col3, #T_f9f2a_row2_col4, #T_f9f2a_row2_col5, #T_f9f2a_row2_col6, #T_f9f2a_row2_col7, #T_f9f2a_row2_col8, #T_f9f2a_row3_col0, #T_f9f2a_row3_col1, #T_f9f2a_row3_col2, #T_f9f2a_row3_col3, #T_f9f2a_row3_col4, #T_f9f2a_row3_col5, #T_f9f2a_row3_col6, #T_f9f2a_row3_col7, #T_f9f2a_row3_col8, #T_f9f2a_row4_col0, #T_f9f2a_row4_col1, #T_f9f2a_row4_col2, #T_f9f2a_row4_col3, #T_f9f2a_row4_col4, #T_f9f2a_row4_col5, #T_f9f2a_row4_col6, #T_f9f2a_row4_col7, #T_f9f2a_row4_col8, #T_f9f2a_row5_col0, #T_f9f2a_row5_col1, #T_f9f2a_row5_col2, #T_f9f2a_row5_col3, #T_f9f2a_row5_col4, #T_f9f2a_row5_col5, #T_f9f2a_row5_col6, #T_f9f2a_row5_col7, #T_f9f2a_row5_col8, #T_f9f2a_row6_col0, #T_f9f2a_row6_col1, #T_f9f2a_row6_col2, #T_f9f2a_row6_col3, #T_f9f2a_row6_col4, #T_f9f2a_row6_col5, #T_f9f2a_row6_col6, #T_f9f2a_row6_col7, #T_f9f2a_row6_col8, #T_f9f2a_row7_col0, #T_f9f2a_row7_col1, #T_f9f2a_row7_col2, #T_f9f2a_row7_col3, #T_f9f2a_row7_col4, #T_f9f2a_row7_col5, #T_f9f2a_row7_col6, #T_f9f2a_row7_col7, #T_f9f2a_row7_col8 {
#   font-weight: ;
# }
# #T_f9f2a_row1_col7, #T_f9f2a_row1_col8 {
#   font-weight: bold;
# }
# </style>
# <table id="T_f9f2a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f9f2a_level0_col0" class="col_heading level0 col0" >T->T</th>
#       <th id="T_f9f2a_level0_col1" class="col_heading level0 col1" >E->T</th>
#       <th id="T_f9f2a_level0_col2" class="col_heading level0 col2" >M->T</th>
#       <th id="T_f9f2a_level0_col3" class="col_heading level0 col3" >E->E</th>
#       <th id="T_f9f2a_level0_col4" class="col_heading level0 col4" >T->E</th>
#       <th id="T_f9f2a_level0_col5" class="col_heading level0 col5" >M->E</th>
#       <th id="T_f9f2a_level0_col6" class="col_heading level0 col6" >M->M</th>
#       <th id="T_f9f2a_level0_col7" class="col_heading level0 col7" >T->M</th>
#       <th id="T_f9f2a_level0_col8" class="col_heading level0 col8" >E->M</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f9f2a_level0_row0" class="row_heading level0 row0" >120_4_4_MET-hist</th>
#       <td id="T_f9f2a_row0_col0" class="data row0 col0" >0.33±0.03</td>
#       <td id="T_f9f2a_row0_col1" class="data row0 col1" >0.24±0.02</td>
#       <td id="T_f9f2a_row0_col2" class="data row0 col2" >0.19±0.01</td>
#       <td id="T_f9f2a_row0_col3" class="data row0 col3" >0.44±0.05</td>
#       <td id="T_f9f2a_row0_col4" class="data row0 col4" >0.43±0.05</td>
#       <td id="T_f9f2a_row0_col5" class="data row0 col5" >0.26±0.06</td>
#       <td id="T_f9f2a_row0_col6" class="data row0 col6" >0.71±0.01</td>
#       <td id="T_f9f2a_row0_col7" class="data row0 col7" >0.34±0.02</td>
#       <td id="T_f9f2a_row0_col8" class="data row0 col8" >0.09±0.03</td>
#     </tr>
#     <tr>
#       <th id="T_f9f2a_level0_row1" class="row_heading level0 row1" >120_4_4_EM-hist</th>
#       <td id="T_f9f2a_row1_col0" class="data row1 col0" >0.38±0.01</td>
#       <td id="T_f9f2a_row1_col1" class="data row1 col1" >0.3±0.02</td>
#       <td id="T_f9f2a_row1_col2" class="data row1 col2" >0.22±0.02</td>
#       <td id="T_f9f2a_row1_col3" class="data row1 col3" >0.48±0.04</td>
#       <td id="T_f9f2a_row1_col4" class="data row1 col4" >0.46±0.04</td>
#       <td id="T_f9f2a_row1_col5" class="data row1 col5" >0.28±0.06</td>
#       <td id="T_f9f2a_row1_col6" class="data row1 col6" >0.65±0.02</td>
#       <td id="T_f9f2a_row1_col7" class="data row1 col7" >0.37±0.03</td>
#       <td id="T_f9f2a_row1_col8" class="data row1 col8" >0.22±0.03</td>
#     </tr>
#     <tr>
#       <th id="T_f9f2a_level0_row2" class="row_heading level0 row2" >t_e-e2e</th>
#       <td id="T_f9f2a_row2_col0" class="data row2 col0" >-1.85±0.02</td>
#       <td id="T_f9f2a_row2_col1" class="data row2 col1" >-1.86±0.02</td>
#       <td id="T_f9f2a_row2_col2" class="data row2 col2" >--</td>
#       <td id="T_f9f2a_row2_col3" class="data row2 col3" >-0.09±0.06</td>
#       <td id="T_f9f2a_row2_col4" class="data row2 col4" >0.49±0.04</td>
#       <td id="T_f9f2a_row2_col5" class="data row2 col5" >--</td>
#       <td id="T_f9f2a_row2_col6" class="data row2 col6" >--</td>
#       <td id="T_f9f2a_row2_col7" class="data row2 col7" >--</td>
#       <td id="T_f9f2a_row2_col8" class="data row2 col8" >--</td>
#     </tr>
#     <tr>
#       <th id="T_f9f2a_level0_row3" class="row_heading level0 row3" >e_t-e2e</th>
#       <td id="T_f9f2a_row3_col0" class="data row3 col0" >-0.86±0.03</td>
#       <td id="T_f9f2a_row3_col1" class="data row3 col1" >0.36±0.02</td>
#       <td id="T_f9f2a_row3_col2" class="data row3 col2" >--</td>
#       <td id="T_f9f2a_row3_col3" class="data row3 col3" >-0.07±0.07</td>
#       <td id="T_f9f2a_row3_col4" class="data row3 col4" >-0.05±0.06</td>
#       <td id="T_f9f2a_row3_col5" class="data row3 col5" >--</td>
#       <td id="T_f9f2a_row3_col6" class="data row3 col6" >--</td>
#       <td id="T_f9f2a_row3_col7" class="data row3 col7" >--</td>
#       <td id="T_f9f2a_row3_col8" class="data row3 col8" >--</td>
#     </tr>
#     <tr>
#       <th id="T_f9f2a_level0_row4" class="row_heading level0 row4" >m_e-e2e</th>
#       <td id="T_f9f2a_row4_col0" class="data row4 col0" >--</td>
#       <td id="T_f9f2a_row4_col1" class="data row4 col1" >--</td>
#       <td id="T_f9f2a_row4_col2" class="data row4 col2" >--</td>
#       <td id="T_f9f2a_row4_col3" class="data row4 col3" >-0.03±0.07</td>
#       <td id="T_f9f2a_row4_col4" class="data row4 col4" >--</td>
#       <td id="T_f9f2a_row4_col5" class="data row4 col5" >0.22±0.06</td>
#       <td id="T_f9f2a_row4_col6" class="data row4 col6" >-0.12±0.02</td>
#       <td id="T_f9f2a_row4_col7" class="data row4 col7" >--</td>
#       <td id="T_f9f2a_row4_col8" class="data row4 col8" >-0.12±0.02</td>
#     </tr>
#     <tr>
#       <th id="T_f9f2a_level0_row5" class="row_heading level0 row5" >e_m-e2e</th>
#       <td id="T_f9f2a_row5_col0" class="data row5 col0" >--</td>
#       <td id="T_f9f2a_row5_col1" class="data row5 col1" >--</td>
#       <td id="T_f9f2a_row5_col2" class="data row5 col2" >--</td>
#       <td id="T_f9f2a_row5_col3" class="data row5 col3" >-0.06±0.07</td>
#       <td id="T_f9f2a_row5_col4" class="data row5 col4" >--</td>
#       <td id="T_f9f2a_row5_col5" class="data row5 col5" >-0.07±0.07</td>
#       <td id="T_f9f2a_row5_col6" class="data row5 col6" >-0.1±0.04</td>
#       <td id="T_f9f2a_row5_col7" class="data row5 col7" >--</td>
#       <td id="T_f9f2a_row5_col8" class="data row5 col8" >0.27±0.02</td>
#     </tr>
#     <tr>
#       <th id="T_f9f2a_level0_row6" class="row_heading level0 row6" >t_m-e2e</th>
#       <td id="T_f9f2a_row6_col0" class="data row6 col0" >-1.86±0.02</td>
#       <td id="T_f9f2a_row6_col1" class="data row6 col1" >--</td>
#       <td id="T_f9f2a_row6_col2" class="data row6 col2" >-1.85±0.02</td>
#       <td id="T_f9f2a_row6_col3" class="data row6 col3" >--</td>
#       <td id="T_f9f2a_row6_col4" class="data row6 col4" >--</td>
#       <td id="T_f9f2a_row6_col5" class="data row6 col5" >--</td>
#       <td id="T_f9f2a_row6_col6" class="data row6 col6" >-0.1±0.02</td>
#       <td id="T_f9f2a_row6_col7" class="data row6 col7" >0.39±0.02</td>
#       <td id="T_f9f2a_row6_col8" class="data row6 col8" >--</td>
#     </tr>
#     <tr>
#       <th id="T_f9f2a_level0_row7" class="row_heading level0 row7" >m_t-e2e</th>
#       <td id="T_f9f2a_row7_col0" class="data row7 col0" >-0.89±0.07</td>
#       <td id="T_f9f2a_row7_col1" class="data row7 col1" >--</td>
#       <td id="T_f9f2a_row7_col2" class="data row7 col2" >0.22±0.01</td>
#       <td id="T_f9f2a_row7_col3" class="data row7 col3" >--</td>
#       <td id="T_f9f2a_row7_col4" class="data row7 col4" >--</td>
#       <td id="T_f9f2a_row7_col5" class="data row7 col5" >--</td>
#       <td id="T_f9f2a_row7_col6" class="data row7 col6" >-0.12±0.02</td>
#       <t

# %% [markdown]
# #### Within-modality Unimodal

# %%
build_table(general_scores, [
    ("T->T", "patchseq", "T->T"), ("E->T", "patchseq", "E->T"), ("M->T", "patchseq", "M->T"), ("E->E", "patchseq", "E->E"), 
    ("T->E", "patchseq", "T->E"), ("M->E", "patchseq", "M->E"), ("M->M", "patchseq", "M->M"), ("T->M", "patchseq", "T->M"), 
    ("E->M", "patchseq", "E->M")],
            ["decoupled"], 2)
# Out:
#                            T->T       E->T       M->T       E->E       T->E  \
# met_100-decoupled      0.3±0.02  0.23±0.02  0.14±0.02  0.33±0.06  0.32±0.06
# met_100_uni-decoupled  0.3±0.02  0.23±0.02  0.14±0.01  0.33±0.06  0.32±0.06
# met_1k-decoupled       0.3±0.01  0.23±0.01  0.15±0.02  0.33±0.06  0.32±0.06
# met_1k_uni-decoupled   0.3±0.01  0.23±0.01  0.14±0.01  0.33±0.06  0.31±0.07
#
#                             M->E       M->M       T->M       E->M
# met_100-decoupled      0.17±0.07  0.63±0.02  0.31±0.04  0.14±0.05
# met_100_uni-decoupled  0.18±0.07  0.62±0.03  0.31±0.04  0.15±0.06
# met_1k-decoupled       0.17±0.07  0.62±0.04  0.31±0.05  0.15±0.06
# met_1k_uni-decoupled   0.17±0.08  0.63±0.02   0.3±0.05  0.13±0.05

# %%
build_table(general_scores, [
    ("T->T", "patchseq", "T->T"), ("E->T", "patchseq", "E->T"), ("M->T", "patchseq", "M->T"), ("E->E", "patchseq", "E->E"), 
    ("T->E", "patchseq", "T->E"), ("M->E", "patchseq", "M->E"), ("M->M", "patchseq", "M->M"), ("T->M", "patchseq", "T->M"), 
    ("E->M", "patchseq", "E->M")],
            ["decoupled"], 2)
# Out:
#                             T->T       E->T        M->T       E->E       T->E  \
# met_100-decoupled      0.11±0.02  0.04±0.01   0.02±0.02  0.23±0.01   0.2±0.01
# met_100_uni-decoupled  0.21±0.02  0.07±0.02  -0.02±0.03  0.31±0.04  0.26±0.04
# met_1k-decoupled       0.25±0.02  0.18±0.01   0.11±0.02  0.32±0.01  0.32±0.01
# met_1k_uni-decoupled   0.26±0.04  0.17±0.05   0.09±0.05  0.33±0.05   0.3±0.06
#
#                             M->E       M->M       T->M        E->M
# met_100-decoupled      0.07±0.02  0.47±0.03  0.12±0.04  -0.06±0.07
# met_100_uni-decoupled  0.07±0.05  0.62±0.01   0.1±0.03  -0.11±0.05
# met_1k-decoupled       0.16±0.02   0.6±0.02  0.29±0.02   0.07±0.03
# met_1k_uni-decoupled   0.15±0.05  0.63±0.02   0.3±0.04    0.1±0.04

# %% [markdown]
# #### Impact of Gradient Freezing

# %%
grad_columns = [("T->T", "patchseq", "T->T"), ("E->T", "patchseq", "E->T"), ("M->T", "patchseq", "M->T"), ("T->T", "smartseq", "T->T (Tasic)"), 
           ("E->E", "patchseq", "E->E"), ("T->E", "patchseq", "T->E"), ("M->E", "patchseq", "M->E"), ("M->M", "patchseq", "M->M"), 
           ("T->M", "patchseq", "T->M"), ("E->M", "patchseq", "E->M"), ("M->M", "EM", "M->M (EM)")]
build_table(general_scores, grad_columns, ["grad"], 2)
# Out:
#                                 T->T       E->T       M->T T->T (Tasic)  \
# met_patchseq_control-grad  0.23±0.05  0.19±0.04  0.13±0.04   -0.16±0.03
# met_patchseq-grad          0.28±0.03  0.23±0.02  0.15±0.02   -0.13±0.03
# met_full-grad               0.3±0.01  0.24±0.01  0.15±0.02   -0.13±0.03
#
#                                 E->E       T->E       M->E       M->M  \
# met_patchseq_control-grad  0.32±0.07   0.3±0.07  0.16±0.08  0.36±0.08
# met_patchseq-grad          0.35±0.07  0.31±0.06  0.14±0.08  0.43±0.05
# met_full-grad              0.35±0.06  0.31±0.07  0.12±0.08  0.41±0.05
#
#                                 T->M       E->M  M->M (EM)
# met_patchseq_control-grad  0.28±0.07  0.19±0.05  0.25±0.09
# met_patchseq-grad          0.29±0.06  0.19±0.06  0.34±0.07
# met_full-grad              0.29±0.04  0.22±0.06  0.64±0.03

# %% [markdown]
# #### Post-hoc Unimodal Coupling

# %%
general_columns = [("T->T", "patchseq", "T->T"), ("E->T", "patchseq", "E->T"), ("M->T", "patchseq", "M->T"), ("T->T", "smartseq", "T->T (Tasic)"), 
           ("E->E", "patchseq", "E->E"), ("T->E", "patchseq", "T->E"), ("M->E", "patchseq", "M->E"), ("M->M", "patchseq", "M->M"), 
           ("T->M", "patchseq", "T->M"), ("E->M", "patchseq", "E->M"), ("M->M", "EM", "M->M (EM)")]
build_table(general_scores, general_columns, ["patch", "full", "complete", "cpl"], 2, 
            exps = ["met-patch", "met-full", "met-complete", "coupled-cpl"])
# Out:
#                    T->T       E->T       M->T T->T (Tasic)       E->E  \
# met-patch     0.24±0.02   0.2±0.02  0.13±0.02   -0.16±0.02  0.34±0.06
# met-full      0.28±0.03  0.23±0.03  0.14±0.02   -0.13±0.02  0.34±0.06
# met-complete  0.29±0.02  0.24±0.03  0.13±0.02     0.4±0.04  0.35±0.05
# coupled-cpl   0.39±0.01  0.15±0.01  0.03±0.02     0.02±0.0  0.65±0.05
#
#                    T->E       M->E       M->M       T->M        E->M  \
# met-patch     0.31±0.07  0.16±0.08  0.37±0.05   0.3±0.04   0.22±0.04
# met-full      0.31±0.06  0.11±0.08   0.4±0.03  0.31±0.03   0.24±0.04
# met-complete  0.31±0.06  0.12±0.09  0.39±0.04   0.3±0.04   0.23±0.05
# coupled-cpl   0.24±0.07  0.01±0.07  0.74±0.02  0.24±0.03  -0.01±0.06
#
#               M->M (EM)
# met-patch     0.24±0.05
# met-full      0.62±0.03
# met-complete  0.62±0.06
# coupled-cpl    0.58±0.0

# %% [markdown]
# #### Variational AE

# %%
var_columns = [("T->T", "patchseq", "T->T"), ("E->T", "patchseq", "E->T"), ("M->T", "patchseq", "M->T"), ("T->T", "smartseq", "T->T (Tasic)"), 
           ("E->E", "patchseq", "E->E"), ("T->E", "patchseq", "T->E"), ("M->E", "patchseq", "M->E"), ("M->M", "patchseq", "M->M"), 
           ("T->M", "patchseq", "T->M"), ("E->M", "patchseq", "E->M"), ("M->M", "EM", "M->M (EM)")]
build_table(general_scores, var_columns, ["patch", "var"], 2)
# Out:
#                      T->T       E->T       M->T T->T (Tasic)       E->E  \
# t_arm-patch     0.37±0.01         --         --    0.03±0.01         --
# e_arm-patch            --         --         --           --  0.55±0.04
# m_arm-patch            --         --         --           --         --
# t_e_arms-patch  0.34±0.01  0.27±0.01         --   -0.07±0.01  0.52±0.04
# t_m_arms-patch  0.24±0.05         --  0.16±0.04   -0.17±0.04         --
# e_m_arms-patch         --         --         --           --  0.34±0.06
# met-patch       0.24±0.02   0.2±0.02  0.13±0.02   -0.16±0.02  0.34±0.06
# t_arm-var       0.32±0.01         --         --    0.01±0.02         --
# e_arm-var              --         --         --           --  0.39±0.08
# m_arm-var              --         --         --           --         --
# t_e_arms-var    0.33±0.01  0.25±0.02         --   -0.01±0.02  0.35±0.06
# t_m_arms-var    0.27±0.03         --  0.12±0.04   -0.11±0.02         --
# e_m_arms-var           --         --         --           --  0.25±0.06
# met-var          0.3±0.02  0.23±0.02  0.14±0.02   -0.07±0.03  0.33±0.06
#
#                      T->E       M->E       M->M       T->M       E->M  \
# t_arm-patch            --         --         --         --         --
# e_arm-patch            --         --         --         --         --
# m_arm-patch            --         --  0.71±0.02         --         --
# t_e_arms-patch  0.33±0.07         --         --         --         --
# t_m_arms-patch         --         --  0.62±0.04  0.28±0.06         --
# e_m_arms-patch         --   0.1±0.11  0.51±0.04         --   0.09±0.1
# met-patch       0.31±0.07  0.16±0.08  0.37±0.05   0.3±0.04  0.22±0.04
# t_arm-var              --         --         --         --         --
# e_arm-var              --         --         --         --         --
# m_arm-var              --         --  0.67±0.05         --         --
# t_e_arms-var    0.34±0.06         --         --         --         --
# t_m_arms-var           --         --  0.54±0.04   0.3±0.05         --
# e_m_arms-var           --  0.15±0.07  0.58±0.13         --  0.13±0.06
# met-var         0.32±0.06  0.16±0.07  0.58±0.03   0.3±0.05  0.15±0.05
#
#                 M->M (EM)
# t_arm-patch            --
# e_arm-patch            --
# m_arm-patch     0.63±0.03
# t_e_arms-patch         --
# t_m_arms-patch  0.53±0.05
# e_m_arms-patch  0.35±0.07
# met-patch       0.24±0.05
# t_arm-var              --
# e_arm-var              --
# m_arm-var       0.61±0.02
# t_e_arms-var           --
# t_m_arms-var    0.45±0.03
# e_m_arms-var     0.43±0.2
# met-var          0.5±0.03

# %% [markdown]
# #### Cross-Modal Deviation

# %%
var_columns = [("T->T", "patchseq", "T->T"), ("E->T", "patchseq", "E->T"), ("M->T", "patchseq", "M->T"), ("T->T", "smartseq", "T->T (Tasic)"), 
           ("E->E", "patchseq", "E->E"), ("T->E", "patchseq", "T->E"), ("M->E", "patchseq", "M->E"), ("M->M", "patchseq", "M->M"), 
           ("T->M", "patchseq", "T->M"), ("E->M", "patchseq", "E->M"), ("M->M", "EM", "M->M (EM)")]
build_table(general_scores, var_columns, ["var", "tight", "loose"], 2, exps = ["met-var", "met-tight", "met-loose"])
# Out:
#                 T->T       E->T       M->T T->T (Tasic)       E->E       T->E  \
# met-var     0.3±0.02  0.23±0.02  0.14±0.02   -0.07±0.03  0.33±0.06  0.32±0.06
# met-tight  0.31±0.02  0.24±0.02  0.14±0.02   -0.05±0.03  0.34±0.06  0.32±0.06
# met-loose  0.29±0.02  0.23±0.02  0.13±0.03   -0.08±0.03  0.32±0.07   0.3±0.07
#
#                 M->E       M->M      T->M       E->M  M->M (EM)
# met-var    0.16±0.07  0.58±0.03  0.3±0.05  0.15±0.05   0.5±0.03
# met-tight  0.15±0.06  0.55±0.04  0.3±0.05  0.17±0.06  0.48±0.05
# met-loose   0.1±0.06  0.57±0.03  0.3±0.06  0.15±0.06   0.5±0.03

# %% [markdown]
# #### Rebalancing

# %%
build_table(general_scores, [
    ("T->T", "patchseq", "T->T"), ("E->T", "patchseq", "E->T"), ("M->T", "patchseq", "M->T"), ("E->E", "patchseq", "E->E"), 
    ("T->E", "patchseq", "T->E"), ("M->E", "patchseq", "M->E"), ("M->M", "patchseq", "M->M"), ("T->M", "patchseq", "T->M"), 
    ("E->M", "patchseq", "E->M")], 
            ["slides", "rebalanced", "test"], 2, exps = ["met-slides", "met_3d_10-rebalanced", "rebalanced-test"])
# Out:
#                            T->T       E->T       M->T       E->E       T->E  \
# met-slides            0.34±0.01  0.27±0.02  0.15±0.03  0.34±0.06  0.34±0.06
# met_3d_10-rebalanced  0.27±0.02  0.21±0.01  0.14±0.01  0.41±0.06  0.31±0.06
# rebalanced-test       0.32±0.01  0.24±0.02  0.15±0.02  0.34±0.06  0.33±0.06
#
#                            M->E       M->M       T->M       E->M
# met-slides            0.12±0.07   0.5±0.03  0.33±0.04  0.21±0.04
# met_3d_10-rebalanced   0.1±0.08  0.62±0.03   0.3±0.03  0.13±0.05
# rebalanced-test       0.15±0.07  0.61±0.04  0.29±0.06  0.13±0.06

# %% [markdown]
# #### Other Platforms

# %%
build_table(general_scores, [
    ("T->T", "patchseq", "T->T"), ("E->T", "patchseq", "E->T"), ("M->T", "patchseq", "M->T"), ("E->E", "patchseq", "E->E"), 
    ("T->E", "patchseq", "T->E"), ("M->E", "patchseq", "M->E"), ("M->M", "patchseq", "M->M"), ("T->M", "patchseq", "T->M"), 
    ("E->M", "patchseq", "E->M"), ("M->M", "EM", "M->M (EM)")], 
            ["tight", "ME", "fMOST"], 2, exps = ["met-tight", "met_3-ME", "met_3-fMOST"])
# Out:
#                   T->T       E->T       M->T       E->E       T->E       M->E  \
# met-tight    0.31±0.02  0.24±0.02  0.14±0.02  0.34±0.06  0.32±0.06  0.15±0.06
# met_3-ME     0.31±0.01  0.24±0.01  0.14±0.02  0.33±0.07  0.32±0.07  0.14±0.06
# met_3-fMOST  0.32±0.01  0.24±0.02  0.14±0.02  0.34±0.06  0.32±0.06  0.13±0.07
#
#                   M->M       T->M       E->M  M->M (EM)
# met-tight    0.55±0.04   0.3±0.05  0.17±0.06  0.48±0.05
# met_3-ME     0.58±0.03  0.31±0.05  0.18±0.06  0.55±0.01
# met_3-fMOST  0.51±0.12  0.28±0.07  0.15±0.05  0.44±0.19

# %%
build_table(general_scores, [
    ("E->E", "patchseq", "E->E"), ("M->E", "patchseq", "M->E"), ("E->E", "ME", "E->E (ME)"), ("M->E", "ME", "M->E (ME)"),
    ("M->M", "patchseq", "M->M"), ("E->M", "patchseq", "E->M"), ("M->M", "ME", "M->M (ME)"), ("E->M", "ME", "E->M (ME)"), 
    ("M->M", "fMOST", "M->M (fMOST)")], 
            ["tight", "ME", "fMOST"], 2, exps = ["met-tight", "met_3-ME", "met_3-fMOST"])
# Out:
#                   E->E       M->E  E->E (ME)  M->E (ME)       M->M       E->M  \
# met-tight    0.34±0.06  0.15±0.06  0.65±0.03  0.87±0.14  0.55±0.04  0.17±0.06
# met_3-ME     0.33±0.07  0.14±0.06  0.58±0.04  0.78±0.12  0.58±0.03  0.18±0.06
# met_3-fMOST  0.34±0.06  0.13±0.07  0.66±0.03  0.84±0.11  0.51±0.12  0.15±0.05
#
#              M->M (ME)  E->M (ME) M->M (fMOST)
# met-tight    0.52±0.04  0.03±0.08    0.55±0.08
# met_3-ME     0.59±0.04   0.1±0.06    0.61±0.07
# met_3-fMOST  0.48±0.14  0.02±0.09    0.51±0.21

# %%
build_table(general_scores, [
    ("E->E", "patchseq", "E->E"), ("M->E", "patchseq", "M->E"), ("E->E", "ME", "E->E (ME)"), ("M->E", "ME", "M->E (ME)"),
    ("M->M", "patchseq", "M->M"), ("E->M", "patchseq", "E->M"), ("M->M", "ME", "M->M (ME)"), ("E->M", "ME", "E->M (ME)"), 
    ("M->M", "fMOST", "M->M (fMOST)")], 
            ["tight", "ME", "fMOST"], 2, exps = ["met-tight", "met_3-ME", "met_3-fMOST"])
# Out:
#                   E->E       M->E  E->E (ME)  M->E (ME)       M->M       E->M  \
# met-tight    0.34±0.06  0.15±0.06  0.85±0.04  0.97±0.12  0.55±0.04  0.17±0.06
# met_3-ME     0.33±0.07  0.14±0.06  0.77±0.05  0.88±0.12  0.58±0.03  0.18±0.06
# met_3-fMOST  0.34±0.06  0.13±0.07  0.85±0.05  0.98±0.13  0.51±0.12  0.15±0.05
#
#              M->M (ME)  E->M (ME) M->M (fMOST)
# met-tight    0.52±0.04  0.03±0.08    0.55±0.08
# met_3-ME     0.59±0.04   0.1±0.06    0.61±0.07
# met_3-fMOST  0.48±0.14  0.02±0.09    0.51±0.21

# %% [markdown]
# #### Group Presentation

# %%
build_table(general_scores, [
    ("T->T", "patchseq", "T->T"), ("E->E", "patchseq", "E->E"), ("M->M", "patchseq", "M->M"), ("E->T", "patchseq", "E->T"), 
    ("M->T", "patchseq", "M->T"), ("T->E", "patchseq", "T->E"), ("M->E", "patchseq", "M->E"), ("T->M", "patchseq", "T->M"), 
    ("E->M", "patchseq", "E->M")], 
            ["patch"], 2, exps = ["t_arm-patch","e_arm-patch", "m_arm-patch", "met-patch"])
# Out:
#                   T->T       E->E       M->M      E->T       M->T       T->E  \
# t_arm-patch  0.37±0.01         --         --        --         --         --
# e_arm-patch         --  0.55±0.04         --        --         --         --
# m_arm-patch         --         --  0.71±0.02        --         --         --
# met-patch    0.24±0.02  0.34±0.06  0.37±0.05  0.2±0.02  0.13±0.02  0.31±0.07
#
#                   M->E      T->M       E->M
# t_arm-patch         --        --         --
# e_arm-patch         --        --         --
# m_arm-patch         --        --         --
# met-patch    0.16±0.08  0.3±0.04  0.22±0.04

# %% [markdown]
# #### ELBO

# %%
build_table(general_scores, [
    ("T->T", "patchseq", "T->T"), ("E->E", "patchseq", "E->E"), ("M->M", "patchseq", "M->M"), ("E->T", "patchseq", "E->T"), 
    ("M->T", "patchseq", "M->T"), ("T->E", "patchseq", "T->E"), ("M->E", "patchseq", "M->E"), ("T->M", "patchseq", "T->M"), 
    ("E->M", "patchseq", "E->M")], 
            ["elbo"], 2)
# Out:
#                     T->T       E->E       M->M        E->T        M->T  \
# t_arm-elbo     0.34±0.02         --         --          --          --
# e_arm-elbo            --  0.46±0.06         --          --          --
# m_arm-elbo            --         --  0.71±0.02          --          --
# met-elbo       0.33±0.01  0.45±0.06  0.67±0.03   0.13±0.02  -0.06±0.04
# met_full-elbo  0.33±0.04  0.46±0.06  0.74±0.02  -0.37±0.19  -0.37±0.19
#
#                      T->E        M->E        T->M        E->M
# t_arm-elbo             --          --          --          --
# e_arm-elbo             --          --          --          --
# m_arm-elbo             --          --          --          --
# met-elbo        0.21±0.08  -0.07±0.08  -0.11±0.09  -0.18±0.07
# met_full-elbo  -0.42±0.31  -0.47±0.18  -0.66±0.29  -0.66±0.13

# %% [markdown]
# #### Trees

# %%
build_table(general_scores, [
    ("T->T", "patchseq", "T->T"), ("E->T", "patchseq", "E->T"), ("M->T", "patchseq", "M->T"), ("E->E", "patchseq", "E->E"), 
    ("T->E", "patchseq", "T->E"), ("M->E", "patchseq", "M->E"), ("M->M", "patchseq", "M->M"), ("T->M", "patchseq", "T->M"), 
    ("E->M", "patchseq", "E->M")], 
            ["ref", "tree"], 2)
# Out:
#                    T->T       E->T       M->T       E->E       T->E  \
# t_arm-ref     0.35±0.01         --         --         --         --
# e_arm-ref            --         --         --  0.47±0.07         --
# m_arm-ref            --         --         --         --         --
# t_e_arms-ref  0.35±0.01  0.26±0.01         --  0.41±0.05  0.34±0.06
# t_m_arms-ref  0.33±0.02         --  0.14±0.02         --         --
# e_m_arms-ref         --         --         --  0.38±0.06         --
# met-ref       0.33±0.01  0.25±0.01  0.15±0.02  0.38±0.06  0.33±0.06
# raw_0-tree    0.35±0.01  0.27±0.01  0.18±0.02  0.35±0.06  0.33±0.06
# raw_10-tree   0.35±0.01  0.27±0.01  0.19±0.02  0.35±0.06  0.33±0.06
# raw_20-tree   0.35±0.01  0.27±0.01  0.19±0.02  0.35±0.06  0.33±0.06
# raw_30-tree   0.35±0.01  0.27±0.01  0.18±0.02  0.34±0.06  0.33±0.06
# raw_40-tree   0.34±0.01  0.28±0.01  0.19±0.02  0.33±0.06  0.33±0.06
# raw_50-tree   0.34±0.01  0.27±0.01  0.19±0.02  0.33±0.06  0.32±0.06
# raw_60-tree   0.33±0.01  0.27±0.02  0.19±0.02  0.32±0.06  0.31±0.06
# raw_70-tree   0.33±0.01  0.28±0.01  0.19±0.02  0.32±0.06  0.31±0.06
# raw_80-tree   0.32±0.01  0.27±0.01  0.19±0.02  0.31±0.06   0.3±0.06
# raw_90-tree   0.27±0.01  0.24±0.01  0.18±0.02  0.27±0.06  0.27±0.06
# raw_100-tree  0.15±0.02  0.14±0.02  0.13±0.02  0.13±0.07  0.13±0.07
#
#                    M->E       M->M       T->M       E->M
# t_arm-ref            --         --         --         --
# e_arm-ref            --         --         --         --
# m_arm-ref            --  0.73±0.01         --         --
# t_e_arms-ref         --         --         --         --
# t_m_arms-ref         --   0.6±0.03  0.29±0.05         --
# e_m_arms-ref  0.13±0.07  0.66±0.03         --  0.11±0.04
# met-ref       0.12±0.06  0.57±0.03  0.32±0.04  0.16±0.05
# raw_0-tree    0.13±0.06  0.44±0.03  0.33±0.04  0.22±0.04
# raw_10-tree   0.14±0.07  0.42±0.03  0.33±0.03  0.22±0.04
# raw_20-tree   0.14±0.06  0.41±0.03  0.33±0.03  0.22±0.05
# raw_30-tree   0.13±0.06  0.39±0.03  0.33±0.03  0.23±0.04
# raw_40-tree   0.14±0.06  0.38±0.03  0.32±0.03  0.24±0.05
# raw_50-tree   0.15±0.05  0.37±0.03  0.32±0.03  0.22±0.04
# raw_60-tree   0.14±0.06  0.34±0.03   0.3±0.03  0.23±0.03
# raw_70-tree   0.15±0.05  0.34±0.03  0.31±0.03  0.24±0.03
# raw_80-tree   0.15±0.06  0.34±0.03   0.3±0.03  0.23±0.03
# raw_90-tree   0.15±0.07  0.24±0.03  0.21±0.03  0.17±0.04
# raw_100-tree  0.11±0.07  0.12±0.03  0.11±0.03  0.11±0.03

# %%
build_table(general_scores, [
    ("T->T", "patchseq", "T->T"), ("E->T", "patchseq", "E->T"), ("M->T", "patchseq", "M->T"), ("E->E", "patchseq", "E->E"), 
    ("T->E", "patchseq", "T->E"), ("M->E", "patchseq", "M->E"), ("M->M", "patchseq", "M->M"), ("T->M", "patchseq", "T->M"), 
    ("E->M", "patchseq", "E->M")], 
            ["tree"], 2)
# Out:
#                    T->T       E->T       M->T       E->E       T->E  \
# raw_0-tree    0.42±0.01  0.34±0.01  0.23±0.02  0.47±0.03  0.46±0.03
# raw_10-tree   0.42±0.01  0.34±0.01  0.23±0.02  0.47±0.03  0.46±0.03
# raw_20-tree   0.42±0.01  0.33±0.01  0.23±0.02  0.47±0.03  0.46±0.03
# raw_30-tree   0.41±0.01  0.34±0.01  0.24±0.01  0.46±0.03  0.46±0.03
# raw_40-tree   0.41±0.01  0.34±0.01  0.24±0.01  0.46±0.03  0.45±0.03
# raw_50-tree    0.4±0.01  0.33±0.02  0.24±0.01  0.46±0.03  0.45±0.03
# raw_60-tree    0.4±0.01  0.33±0.01  0.24±0.02  0.45±0.03  0.45±0.03
# raw_70-tree   0.39±0.01  0.34±0.02  0.24±0.01  0.45±0.03  0.44±0.03
# raw_80-tree   0.39±0.01  0.33±0.01  0.24±0.01  0.44±0.03  0.43±0.03
# raw_90-tree   0.33±0.01   0.3±0.01  0.23±0.01  0.39±0.03  0.39±0.03
# raw_100-tree  0.19±0.01  0.18±0.01  0.17±0.01  0.22±0.05  0.21±0.05
#
#                    M->E       M->M       T->M       E->M
# raw_0-tree    0.23±0.05  0.45±0.03  0.35±0.03  0.24±0.03
# raw_10-tree   0.22±0.05  0.42±0.03  0.34±0.03  0.24±0.03
# raw_20-tree   0.21±0.06  0.42±0.03  0.34±0.03  0.23±0.03
# raw_30-tree   0.22±0.06  0.41±0.03  0.34±0.03  0.24±0.03
# raw_40-tree   0.22±0.04  0.39±0.03  0.33±0.03  0.24±0.03
# raw_50-tree   0.24±0.05  0.39±0.03  0.33±0.03  0.23±0.04
# raw_60-tree   0.24±0.04  0.35±0.03  0.31±0.03  0.24±0.04
# raw_70-tree   0.24±0.05  0.35±0.03  0.32±0.03  0.26±0.03
# raw_80-tree   0.24±0.04  0.35±0.03  0.31±0.03  0.25±0.03
# raw_90-tree   0.25±0.05  0.25±0.03  0.22±0.03  0.19±0.03
# raw_100-tree  0.19±0.06  0.13±0.03  0.12±0.03  0.11±0.03

# %% [markdown]
# #### Multisample

# %%
build_table(general_scores, [
    ("T->T", "patchseq", "T->T"), ("E->T", "patchseq", "E->T"), ("M->T", "patchseq", "M->T"), ("E->E", "patchseq", "E->E"), 
    ("T->E", "patchseq", "T->E"), ("M->E", "patchseq", "M->E"), ("M->M", "patchseq", "M->M"), ("T->M", "patchseq", "T->M"), 
    ("E->M", "patchseq", "E->M")], 
            ["fixed", "multisample"], 2)
# Out:
#                                T->T       E->T       M->T       E->E  \
# met_3d_100-fixed          0.33±0.01  0.25±0.01  0.14±0.02  0.38±0.06
# met_10d_100-fixed         0.38±0.01  0.29±0.01  0.16±0.02  0.54±0.05
# met_n5-multisample        0.33±0.02  0.25±0.02  0.15±0.02  0.38±0.06
# met_n10-multisample       0.34±0.01  0.26±0.02  0.15±0.02  0.38±0.06
# met_n100-multisample      0.34±0.01  0.26±0.01  0.16±0.02  0.38±0.06
# met_10d_n100-multisample  0.38±0.02  0.29±0.01  0.16±0.02  0.54±0.06
#
#                                T->E       M->E       M->M       T->M  \
# met_3d_100-fixed          0.33±0.06  0.13±0.07  0.57±0.03  0.32±0.05
# met_10d_100-fixed         0.35±0.06  0.02±0.06  0.63±0.03  0.34±0.04
# met_n5-multisample        0.33±0.06  0.13±0.08  0.56±0.04  0.32±0.05
# met_n10-multisample       0.33±0.06  0.14±0.07  0.58±0.03  0.32±0.05
# met_n100-multisample      0.33±0.06  0.13±0.08  0.57±0.04  0.32±0.04
# met_10d_n100-multisample  0.34±0.06  0.03±0.07  0.64±0.03  0.33±0.04
#
#                                E->M
# met_3d_100-fixed          0.14±0.04
# met_10d_100-fixed          0.2±0.06
# met_n5-multisample        0.15±0.04
# met_n10-multisample       0.14±0.06
# met_n100-multisample      0.16±0.04
# met_10d_n100-multisample   0.2±0.07

# %% [markdown]
# #### Cross-only

# %%
build_table(general_scores, [
    ("T->T", "patchseq", "T->T"), ("E->T", "patchseq", "E->T"), ("M->T", "patchseq", "M->T"), ("E->E", "patchseq", "E->E"), 
    ("T->E", "patchseq", "T->E"), ("M->E", "patchseq", "M->E"), ("M->M", "patchseq", "M->M"), ("T->M", "patchseq", "T->M"), 
    ("E->M", "patchseq", "E->M")], 
            ["fixed", "cross"], 2)
# Out:
#                         T->T        E->T        M->T        E->E        T->E  \
# met_3d_100-fixed   0.33±0.01   0.25±0.01   0.14±0.02   0.38±0.06   0.33±0.06
# e_m-cross                 --          --          --   -0.79±0.2          --
# e_t-cross          0.35±0.01   0.25±0.01          --  -0.78±0.14  -0.79±0.15
# m_e-cross                 --          --          --   0.44±0.06          --
# m_t-cross          0.35±0.01          --   0.12±0.02          --          --
# no_m-cross         0.34±0.01   0.25±0.02   0.13±0.03   0.39±0.06   0.33±0.06
# t_e-cross         -1.94±0.02  -1.94±0.02          --   0.46±0.06    0.3±0.06
# t_m-cross         -1.95±0.02          --  -1.94±0.02          --          --
#
#                        M->E       M->M       T->M       E->M
# met_3d_100-fixed  0.13±0.07  0.57±0.03  0.32±0.05  0.14±0.04
# e_m-cross         -0.75±0.2  0.72±0.02         --   0.1±0.05
# e_t-cross                --         --         --         --
# m_e-cross         0.01±0.11  -0.1±0.03         --  -0.1±0.03
# m_t-cross                --  -0.1±0.03  -0.1±0.03         --
# no_m-cross        0.11±0.07  0.26±0.08  0.34±0.04   0.2±0.04
# t_e-cross                --         --         --         --
# t_m-cross                --  0.75±0.01  0.31±0.05         --

# %% [markdown]
# #### End-to-End

# %%
build_table(general_scores, [
    ("T->T", "patchseq", "T->T"), ("E->T", "patchseq", "E->T"), ("M->T", "patchseq", "M->T"), ("E->E", "patchseq", "E->E"), 
    ("T->E", "patchseq", "T->E"), ("M->E", "patchseq", "M->E"), ("M->M", "patchseq", "M->M"), ("T->M", "patchseq", "T->M"), 
    ("E->M", "patchseq", "E->M")], 
            ["fixed", "end2end", "end2end_10d", "end2end_noinf", "end2end_fixed"], 2)
# Out:
#                          T->T        E->T        M->T        E->E        T->E  \
# met_3d_100-fixed    0.33±0.01   0.25±0.01   0.14±0.02   0.38±0.06   0.33±0.06
# met_10d_100-fixed   0.38±0.01   0.29±0.01   0.16±0.02   0.54±0.05   0.35±0.06
# e_m-end2end                --          --          --  -0.97±0.24          --
# e_t-end2end        -0.41±0.17   0.26±0.02          --  -0.75±0.17   -0.8±0.12
# m_e-end2end                --          --          --  -0.12±0.16          --
# m_t-end2end        -0.44±0.17          --   0.13±0.02          --          --
# m_cpl_t-end2end     0.35±0.01          --  -0.02±0.04          --          --
# t_e-end2end        -1.94±0.02  -1.95±0.02          --  -0.22±0.16   0.32±0.06
# t_m-end2end        -1.94±0.02          --  -1.94±0.02          --          --
# e_m-end2end_10d            --          --          --  -0.69±0.12          --
# e_t-end2end_10d    -0.19±0.07    0.3±0.02          --  -0.68±0.21   -0.67±0.2
# m_e-end2end_10d            --          --          --  -0.24±0.09          --
# m_t-end2end_10d     -0.14±0.1          --   0.16±0.02          --          --
# t_e-end2end_10d    -1.95±0.02  -1.97±0.02          --  -0.11±0.11   0.35±0.06
# t_m-end2end_10d    -1.94±0.02          --  -1.94±0.02          --          --
# e_m-end2end_noinf          --          --          --  -0.53±0.15          --
# e_t-end2end_noinf  -0.25±0.07   0.25±0.01          --  -0.59±0.11  -0.39±0.09
# m_e-end2end_noinf          --          --          --  -0.05±0.08          --
# m_t-end2end_noinf  -0.46±0.11          --   0.13±0.02          --          --
# t_e-end2end_noinf  -1.96±0.02  -1.94±0.02          --   -0.3±0.13   0.29±0.07
# t_m-end2end_noinf  -1.96±0.02          --  -1.94±0.02          --          --
# e_m-end2end_fixed          --          --          --   -0.42±0.1          --
# e_t-end2end_fixed   -0.9±0.08   0.29±0.01          --  -0.66±0.26  -0.35±0.15
# m_e-end2end_fixed          --          --          --  -0.07±0.09          --
# m_t-end2end_fixed  -0.84±0.09          --   0.16±0.02          --          --
# t_e-end2end_fixed  -1.95±0.02  -1.95±0.02          --  -0.16±0.07   0.35±0.06
# t_m-end2end_fixed  -1.95±0.02          --  -1.95±0.02          --          --
#
#                          M->E        M->M       T->M       E->M
# met_3d_100-fixed    0.13±0.07   0.57±0.03  0.32±0.05  0.14±0.04
# met_10d_100-fixed   0.02±0.06   0.63±0.03  0.34±0.04   0.2±0.06
# e_m-end2end        -0.81±0.18  -0.18±0.11         --  0.25±0.04
# e_t-end2end                --          --         --         --
# m_e-end2end         0.14±0.07   -0.1±0.03         --  -0.1±0.03
# m_t-end2end                --   -0.1±0.03  -0.1±0.03         --
# m_cpl_t-end2end            --   0.18±0.06  0.33±0.04         --
# t_e-end2end                --          --         --         --
# t_m-end2end                --  -0.34±0.09  0.35±0.04         --
# e_m-end2end_10d    -0.65±0.11  -0.14±0.11         --  0.25±0.04
# e_t-end2end_10d            --          --         --         --
# m_e-end2end_10d     0.16±0.07   -0.1±0.03         --  -0.1±0.03
# m_t-end2end_10d            --   -0.1±0.03  -0.1±0.03         --
# t_e-end2end_10d            --          --         --         --
# t_m-end2end_10d            --   -0.23±0.1  0.36±0.03         --
# e_m-end2end_noinf  -0.58±0.14   -0.1±0.06         --  0.22±0.05
# e_t-end2end_noinf          --          --         --         --
# m_e-end2end_noinf    0.1±0.07   -0.1±0.03         --  -0.1±0.03
# m_t-end2end_noinf          --   -0.1±0.03  -0.1±0.03         --
# t_e-end2end_noinf          --          --         --         --
# t_m-end2end_noinf          --  -0.31±0.07  0.28±0.04         --
# e_m-end2end_fixed   -0.53±0.1  -0.08±0.04         --  0.25±0.04
# e_t-end2end_fixed          --          --         --         --
# m_e-end2end_fixed    0.1±0.07   -0.1±0.03         --  -0.1±0.03
# m_t-end2end_fixed          --   -0.1±0.03  -0.1±0.03         --
# t_e-end2end_fixed          --          --         --         --
# t_m-end2end_fixed          --  -0.09±0.03  0.36±0.04         --

# %% [markdown]
# #### Reference

# %%
build_table(general_scores, [
    ("T->T", "patchseq", "T->T"), ("E->T", "patchseq", "E->T"), ("M->T", "patchseq", "M->T"), ("E->E", "patchseq", "E->E"), 
    ("T->E", "patchseq", "T->E"), ("M->E", "patchseq", "M->E"), ("M->M", "patchseq", "M->M"), ("T->M", "patchseq", "T->M"), 
    ("E->M", "patchseq", "E->M")], 
            ["ref", "fixed"], 2)
# Out:
#                        T->T       E->T       M->T       E->E       T->E  \
# t_arm-ref         0.35±0.01         --         --         --         --
# e_arm-ref                --         --         --  0.47±0.07         --
# m_arm-ref                --         --         --         --         --
# t_e_arms-ref      0.35±0.01  0.26±0.01         --  0.41±0.05  0.34±0.06
# t_m_arms-ref      0.33±0.02         --  0.14±0.02         --         --
# e_m_arms-ref             --         --         --  0.38±0.06         --
# met_3d_100-fixed  0.33±0.01  0.25±0.01  0.14±0.02  0.38±0.06  0.33±0.06
#
#                        M->E       M->M       T->M       E->M
# t_arm-ref                --         --         --         --
# e_arm-ref                --         --         --         --
# m_arm-ref                --  0.73±0.01         --         --
# t_e_arms-ref             --         --         --         --
# t_m_arms-ref             --   0.6±0.03  0.29±0.05         --
# e_m_arms-ref      0.13±0.07  0.66±0.03         --  0.11±0.04
# met_3d_100-fixed  0.13±0.07  0.57±0.03  0.32±0.05  0.14±0.04

# %% [markdown]
# #### Including EM

# %%
var_columns = [("T->T", "patchseq", "T->T"), ("E->T", "patchseq", "E->T"), ("M->T", "patchseq", "M->T"), 
           ("E->E", "patchseq", "E->E"), ("T->E", "patchseq", "T->E"), ("M->E", "patchseq", "M->E"), ("M->M", "patchseq", "M->M"), 
           ("T->M", "patchseq", "T->M"), ("E->M", "patchseq", "E->M"), ("M->M", "EM", "M->M (EM)")]
build_table(general_scores, var_columns, ["fixed", "rebalanced_full"], 2)
# Out:
#                                   T->T       E->T       M->T       E->E  \
# met_3d_100-fixed             0.33±0.01  0.25±0.01  0.14±0.02  0.38±0.06
# met_10d_100-fixed            0.38±0.01  0.29±0.01  0.16±0.02  0.54±0.05
# met_2d_100-rebalanced_full    0.3±0.01  0.24±0.02  0.09±0.04  0.33±0.07
# met_3d_100-rebalanced_full   0.32±0.02  0.26±0.02  0.11±0.03  0.39±0.06
# met_10d_100-rebalanced_full  0.37±0.01  0.29±0.01  0.16±0.02  0.54±0.05
#
#                                   T->E       M->E       M->M       T->M  \
# met_3d_100-fixed             0.33±0.06  0.13±0.07  0.57±0.03  0.32±0.05
# met_10d_100-fixed            0.35±0.06  0.02±0.06  0.63±0.03  0.34±0.04
# met_2d_100-rebalanced_full   0.32±0.06  0.14±0.07  0.44±0.04  0.32±0.04
# met_3d_100-rebalanced_full   0.33±0.06  0.12±0.07  0.49±0.03  0.35±0.05
# met_10d_100-rebalanced_full  0.34±0.06  0.06±0.07  0.58±0.02  0.36±0.05
#
#                                   E->M  M->M (EM)
# met_3d_100-fixed             0.14±0.04  0.52±0.02
# met_10d_100-fixed             0.2±0.06  0.52±0.03
# met_2d_100-rebalanced_full   0.22±0.05  0.71±0.01
# met_3d_100-rebalanced_full   0.25±0.05  0.74±0.01
# met_10d_100-rebalanced_full  0.28±0.05  0.78±0.02

# %% [markdown]
# #### Reconstruction Loss

# %%
build_table(general_scores, [
    ("T->T", "patchseq", "T->T"), ("E->T", "patchseq", "E->T"), ("M->T", "patchseq", "M->T"), ("E->E", "patchseq", "E->E"), 
    ("T->E", "patchseq", "T->E"), ("M->E", "patchseq", "M->E"), ("M->M", "patchseq", "M->M"), ("T->M", "patchseq", "T->M"), 
    ("E->M", "patchseq", "E->M")], ["recon"], 2)
# Out:
#                             T->T        E->T        M->T        E->E  \
# uncoupled-recon        0.44±0.02  -0.55±0.17  -0.64±0.14   0.76±0.03
# coupled-recon          0.29±0.05   0.22±0.04    0.1±0.04   0.54±0.06
# cross-recon            0.42±0.01   0.24±0.02   0.24±0.01    0.7±0.03
# cross_coupled-recon    0.31±0.06   0.26±0.06   0.17±0.02   0.53±0.08
# all_to_T-recon         0.42±0.02   0.32±0.01   0.19±0.02  -0.08±0.07
# all_to_E-recon        -1.84±0.01  -1.84±0.01  -1.85±0.02   0.63±0.04
# all_to_M-recon        -1.84±0.02  -1.84±0.02  -1.84±0.02  -0.09±0.07
# coupled_nonorm-recon    0.37±0.0    0.17±0.0    0.04±0.0    0.76±0.0
# cross_grad-recon       0.34±0.02   0.27±0.02   0.21±0.02   0.62±0.03
#
#                             T->E        M->E        M->M        T->M  \
# uncoupled-recon       -1.02±0.42  -0.87±0.27   0.76±0.01  -0.81±0.11
# coupled-recon          0.42±0.04   0.07±0.17   0.39±0.05   0.15±0.09
# cross-recon            0.47±0.05   0.28±0.05   0.72±0.01   0.39±0.03
# cross_coupled-recon    0.45±0.05   0.22±0.05   0.36±0.04   0.32±0.03
# all_to_T-recon        -0.08±0.07  -0.08±0.07  -0.12±0.02  -0.12±0.02
# all_to_E-recon         0.42±0.05   0.19±0.07  -0.12±0.02  -0.12±0.02
# all_to_M-recon        -0.09±0.07  -0.08±0.07   0.69±0.03   0.38±0.03
# coupled_nonorm-recon    0.13±0.0   -0.46±0.0    0.64±0.0     0.1±0.0
# cross_grad-recon       0.43±0.05   0.17±0.07   0.55±0.02   0.35±0.02
#
#                             E->M
# uncoupled-recon       -0.76±0.13
# coupled-recon          0.02±0.08
# cross-recon            0.17±0.03
# cross_coupled-recon    0.22±0.03
# all_to_T-recon        -0.12±0.02
# all_to_E-recon        -0.12±0.02
# all_to_M-recon         0.17±0.02
# coupled_nonorm-recon   -0.21±0.0
# cross_grad-recon       0.15±0.04

# %% [markdown]
# #### Arbor Densities EM vs MET

# %%
var_columns = [("T->T", "patchseq", "T->T"), ("E->T", "patchseq", "E->T"), ("M->T", "patchseq", "M->T"), 
           ("E->E", "patchseq", "E->E"), ("T->E", "patchseq", "T->E"), ("M->E", "patchseq", "M->E"), ("M->M", "patchseq", "M->M"), 
           ("T->M", "patchseq", "T->M"), ("E->M", "patchseq", "E->M")]
build_table(general_scores, var_columns, ["hist", "densities", "direct", "tree", "partial"], 2, 
            ["120_8_4_MET-hist", "120_8_4-densities", "120_8_4_EM-hist",
             "10d_MET-hist", "10d_patch-hist", "10d_EM-hist", "MtoM_EtoM_patch-partial", "MtoM_EtoM_EM-partial",
             "t_m-direct", "m_t-direct","e_m-direct", "m_e-direct", "raw_0-tree"])
# Out:
#                                T->T       E->T        M->T        E->E  \
# 120_8_4_MET-hist          0.33±0.02  0.24±0.02   0.21±0.01   0.44±0.05
# 120_8_4-densities         0.38±0.01  0.28±0.02   0.24±0.01   0.48±0.04
# 120_8_4_EM-hist           0.38±0.02  0.29±0.01   0.23±0.02   0.48±0.04
# 10d_MET-hist               0.4±0.03  0.31±0.02   0.24±0.01   0.75±0.02
# 10d_patch-hist            0.43±0.01  0.34±0.01   0.26±0.01   0.76±0.03
# 10d_EM-hist               0.44±0.01  0.34±0.01   0.23±0.02   0.77±0.02
# MtoM_EtoM_patch-partial          --         --          --  -0.09±0.07
# MtoM_EtoM_EM-partial             --         --          --  -0.07±0.07
# t_m-direct               -1.84±0.02         --  -1.85±0.02          --
# m_t-direct               -0.36±0.07         --    0.2±0.02          --
# e_m-direct                       --         --          --  -0.08±0.07
# m_e-direct                       --         --          --  -0.11±0.15
# raw_0-tree                0.42±0.01  0.34±0.01   0.23±0.02   0.47±0.03
#
#                               T->E        M->E        M->M       T->M  \
# 120_8_4_MET-hist         0.43±0.05   0.28±0.06   0.68±0.02   0.3±0.02
# 120_8_4-densities        0.45±0.05    0.3±0.05   0.71±0.01  0.31±0.04
# 120_8_4_EM-hist          0.46±0.04   0.29±0.07   0.61±0.02  0.34±0.03
# 10d_MET-hist             0.45±0.04   0.21±0.07    0.7±0.01  0.33±0.04
# 10d_patch-hist           0.47±0.04   0.24±0.07   0.72±0.01  0.34±0.03
# 10d_EM-hist              0.49±0.03   0.12±0.09   0.69±0.02  0.36±0.03
# MtoM_EtoM_patch-partial         --  -0.08±0.07   0.71±0.02         --
# MtoM_EtoM_EM-partial            --  -0.07±0.07   0.72±0.02         --
# t_m-direct                      --          --  -0.26±0.07  0.36±0.03
# m_t-direct                      --          --   -0.1±0.03  -0.1±0.03
# e_m-direct                      --  -0.08±0.08  -0.19±0.06         --
# m_e-direct                      --   0.25±0.07   -0.1±0.03         --
# raw_0-tree               0.46±0.03   0.23±0.05   0.45±0.03  0.35±0.03
#
#                               E->M
# 120_8_4_MET-hist         0.07±0.03
# 120_8_4-densities         0.1±0.05
# 120_8_4_EM-hist          0.21±0.04
# 10d_MET-hist             0.12±0.04
# 10d_patch-hist           0.16±0.05
# 10d_EM-hist              0.21±0.04
# MtoM_EtoM_patch-partial   0.1±0.04
# MtoM_EtoM_EM-partial     0.16±0.02
# t_m-direct                      --
# m_t-direct                      --
# e_m-direct               0.24±0.02
# m_e-direct               -0.1±0.03
# raw_0-tree               0.24±0.03

# %%
var_columns = [("T->T", "patchseq", "T->T"), ("E->T", "patchseq", "E->T"), ("M->T", "patchseq", "M->T"), 
           ("E->E", "patchseq", "E->E"), ("T->E", "patchseq", "T->E"), ("M->E", "patchseq", "M->E"), ("M->M", "patchseq", "M->M"), 
           ("T->M", "patchseq", "T->M"), ("E->M", "patchseq", "E->M"), ("M->M", "EM", "M->M (EM)")]
build_table(general_scores, var_columns, ["hist", "densities", "direct", "tree"], 2, 
            ["120_8_4_MET-hist", "120_8_4-densities", "120_8_4_EM-hist",
             "10d_MET-hist", "10d_patch-hist", "10d_EM-hist",
             "t_m-direct", "m_t-direct","e_m-direct", "m_e-direct", "raw_0-tree"])
# Out:
#                          T->T       E->T        M->T        E->E       T->E  \
# 120_8_4_MET-hist    0.33±0.02  0.24±0.02   0.21±0.01   0.44±0.05  0.43±0.05
# 120_8_4-densities   0.38±0.01  0.28±0.02   0.24±0.01   0.48±0.04  0.45±0.05
# 120_8_4_EM-hist     0.38±0.02  0.29±0.01   0.23±0.02   0.48±0.04  0.46±0.04
# t_m-direct         -1.84±0.02         --  -1.85±0.02          --         --
# m_t-direct         -0.36±0.07         --    0.2±0.02          --         --
# e_m-direct                 --         --          --  -0.08±0.07         --
# m_e-direct                 --         --          --  -0.11±0.15         --
# raw_0-tree          0.42±0.01  0.34±0.01   0.23±0.02   0.47±0.03  0.46±0.03
#
#                          M->E        M->M       T->M       E->M  M->M (EM)
# 120_8_4_MET-hist    0.28±0.06   0.68±0.02   0.3±0.02  0.07±0.03  0.49±0.01
# 120_8_4-densities    0.3±0.05   0.71±0.01  0.31±0.04   0.1±0.05  0.53±0.01
# 120_8_4_EM-hist     0.29±0.07   0.61±0.02  0.34±0.03  0.21±0.04  0.64±0.01
# t_m-direct                 --  -0.26±0.07  0.36±0.03         --         --
# m_t-direct                 --   -0.1±0.03  -0.1±0.03         --         --
# e_m-direct         -0.08±0.08  -0.19±0.06         --  0.24±0.02         --
# m_e-direct          0.25±0.07   -0.1±0.03         --  -0.1±0.03         --
# raw_0-tree          0.23±0.05   0.45±0.03  0.35±0.03  0.24±0.03         --

# %%
var_columns = [("T->T", "patchseq", "T->T"), ("E->T", "patchseq", "E->T"), ("M->T", "patchseq", "M->T"), 
           ("E->E", "patchseq", "E->E"), ("T->E", "patchseq", "T->E"), ("M->E", "patchseq", "M->E"), ("M->M", "patchseq", "M->M"), 
           ("T->M", "patchseq", "T->M"), ("E->M", "patchseq", "E->M")]
build_table(general_scores, var_columns, ["hist", "densities"], 2, 
            ["120_8_4_MET-hist", "120_8_4-densities", "120_8_4_EM-hist", "120_4_4_MET-hist", "120_4_4-densities", "120_4_4_EM-hist"])
# Out:
#                         T->T       E->T       M->T       E->E       T->E  \
# 120_8_4_MET-hist   0.33±0.02  0.24±0.02  0.21±0.01  0.44±0.05  0.43±0.05
# 120_8_4-densities  0.38±0.01  0.28±0.02  0.24±0.01  0.48±0.04  0.45±0.05
# 120_8_4_EM-hist    0.38±0.02  0.29±0.01  0.23±0.02  0.48±0.04  0.46±0.04
# 120_4_4_MET-hist   0.33±0.03  0.24±0.02  0.19±0.01  0.44±0.05  0.43±0.05
# 120_4_4-densities  0.38±0.01  0.28±0.01  0.23±0.01  0.47±0.04  0.45±0.04
# 120_4_4_EM-hist    0.38±0.01   0.3±0.02  0.22±0.02  0.48±0.04  0.46±0.04
#
#                         M->E       M->M       T->M       E->M
# 120_8_4_MET-hist   0.28±0.06  0.68±0.02   0.3±0.02  0.07±0.03
# 120_8_4-densities   0.3±0.05  0.71±0.01  0.31±0.04   0.1±0.05
# 120_8_4_EM-hist    0.29±0.07  0.61±0.02  0.34±0.03  0.21±0.04
# 120_4_4_MET-hist   0.26±0.06  0.71±0.01  0.34±0.02  0.09±0.03
# 120_4_4-densities  0.29±0.06  0.73±0.01  0.34±0.04  0.14±0.04
# 120_4_4_EM-hist    0.28±0.06  0.65±0.02  0.37±0.03  0.22±0.03

# %% [markdown]
# #### Direct Regression

# %%
build_table(general_scores, [
    ("E->T", "patchseq", "E->T"), ("M->T", "patchseq", "M->T"), ("E->E", "patchseq", "E->E"), 
    ("T->E", "patchseq", "T->E"), ("M->E", "patchseq", "M->E"), ("M->M", "patchseq", "M->M"), ("T->M", "patchseq", "T->M"), 
    ("E->M", "patchseq", "E->M")], ["direct"], 2)
# Out:
#                 E->T        M->T        E->E T->E        M->E        M->M  \
# t_m-direct        --  -1.85±0.02          --   --          --  -0.26±0.07
# m_t-direct        --    0.2±0.02          --   --          --   -0.1±0.03
# e_m-direct        --          --  -0.08±0.07   --  -0.08±0.08  -0.19±0.06
# m_e-direct        --          --  -0.11±0.15   --   0.25±0.07   -0.1±0.03
# t_m_100d-direct   --  -1.85±0.02          --   --          --   -0.1±0.03
# m_t_100d-direct   --   0.24±0.01          --   --          --   -0.1±0.03
# e_m_100d-direct   --          --  -0.07±0.07   --  -0.07±0.07  -0.08±0.03
# m_e_100d-direct   --          --  -0.04±0.07   --   0.25±0.06   -0.1±0.03
#
#                       T->M       E->M
# t_m-direct       0.36±0.03         --
# m_t-direct       -0.1±0.03         --
# e_m-direct              --  0.24±0.02
# m_e-direct              --  -0.1±0.03
# t_m_100d-direct  0.36±0.02         --
# m_t_100d-direct  -0.1±0.03         --
# e_m_100d-direct         --  0.25±0.02
# m_e_100d-direct         --  -0.1±0.03

# %% [markdown]
# ### Binarizing the Transcriptomic Data

# %% [markdown]
# #### Setup

# %%
binary_targets = {
    "patch_binary": {
        "query": {"platforms": ["patchseq"], "formats": [("logcpm",)]},
        "modalities": ["T"],
        "loss": {
            "formats": {"T": ["logcpm"]},
            "losses": {"logcpm": "bce"},
            "transform": {"logcpm": {"binarize": 0.1}}},
        "groups": {"binary"},
        "display": None
    },
    "smart_binary": {
        "query": {"platforms": ["smartseq"], "formats": [("logcpm",)]},
        "modalities": ["T"],
        "loss": {
            "formats": {"T": ["logcpm"]},
            "losses": {"logcpm": "bce"},
            "transform": {"logcpm": {"binarize": 0.1}}},
        "groups": {"binary"},
        "display": None
    },
    "multimodal_binary": {
        "query": {"formats": [("logcpm", "pca-ipfx", "arbors")]},
        "modalities": ["T", "E", "M"],
        "loss": {
            "formats": {"T": ["logcpm"], "E": ["pca-ipfx"], "M": ["arbors"]},
            "losses": {"logcpm": "bce", "pca-ipfx": "feature_r2", "arbors": "sample_r2"},
            "transform": {"logcpm": {"binarize": 0.1}}},
        "groups": {"binary"},
        "display": {"E": lambda x: 1 - x, "M": lambda x: 1 - x}
    }
}

# %%
binary_plan = generate_recon_plan([], binary_targets)
binary_accs = run_recon_plan(binary_plan, binary_targets, met_data, all_experiments)
binary_scores = compute_scores(binary_accs)
# Out:
# Running target patch_binary:
# Generating t_m_arms_patch-binary - 10: T -> T
# Complete
#
# Running target smart_binary:
# Generating t_m_arms_patch-binary - 10: T -> T
# Complete
#
# Running target multimodal_binary:
# Generating t_m_arms_patch-binary - 10: T -> T
# Complete

# %% [markdown]
# #### Transcriptomic Cross-Entropy

# %%
binary_columns = [("T->T", "patch_binary", "T->T"), ("T->T", "smart_binary", "T->T (Tasic)")]
build_table(binary_scores, binary_columns, ["binary"], 3)
# Out:
#                               T->T T->T (Tasic)
# t_arm_patch-binary     0.396±0.002  0.497±0.003
# t_arm_smart-binary     0.692±0.035  0.329±0.001
# t_arm_both-binary      0.397±0.001  0.329±0.001
# met_patch-binary       0.435±0.002  0.515±0.002
# t_e_arms_patch-binary  0.423±0.003  0.505±0.002
# t_m_arms_patch-binary  0.443±0.005  0.528±0.005

# %% [markdown]
# #### Multimodal Performance

# %%
binary_met_columns = [
    ("T->T", "multimodal_binary", "T->T (BCE)"), ("E->T", "multimodal_binary", "E->T (BCE)"), ("M->T", "multimodal_binary", "M->T (BCE)"), 
    ("E->E", "multimodal_binary", "E->E"), ("T->E", "multimodal_binary", "T->E"), ("M->E", "multimodal_binary", "M->E"), 
    ("M->M", "multimodal_binary", "M->M"), ("T->M", "multimodal_binary", "T->M"), ("E->M", "multimodal_binary", "E->M")]
build_table(binary_scores, binary_met_columns, ["binary"], 2)
# Out:
#                       T->T (BCE) E->T (BCE) M->T (BCE)       E->E       T->E  \
# t_arm_patch-binary      0.38±0.0         --         --         --         --
# t_arm_smart-binary     0.65±0.03         --         --         --         --
# t_arm_both-binary       0.38±0.0         --         --         --         --
# met_patch-binary        0.42±0.0   0.43±0.0  0.45±0.01  0.32±0.06  0.29±0.06
# t_e_arms_patch-binary   0.41±0.0   0.43±0.0         --  0.49±0.04  0.32±0.07
# t_m_arms_patch-binary  0.43±0.01         --   0.45±0.0         --         --
#
#                             M->E       M->M       T->M       E->M
# t_arm_patch-binary            --         --         --         --
# t_arm_smart-binary            --         --         --         --
# t_arm_both-binary             --         --         --         --
# met_patch-binary       0.15±0.07   0.4±0.06   0.3±0.04  0.22±0.04
# t_e_arms_patch-binary         --         --         --         --
# t_m_arms_patch-binary         --  0.56±0.15  0.25±0.08         --

# %% [markdown]
# ### Handcrafted Morphology Features

# %% [markdown]
# #### Setup

# %%
ivscc_targets = {
    "ivscc-patchseq": {
        "query": {"formats": [("logcpm", "pca-ipfx", "arbors", "ivscc")]},
        "modalities": ["T", "E", "M"],
        "loss": {
            "formats": {"T": ["logcpm"], "E": ["pca-ipfx"], "M": ["ivscc"]},
            "losses": {"logcpm": "sample_r2", "pca-ipfx": "sample_r2", "ivscc": "sample_r2"},
            "transform": {}},
        "groups": {"ivscc"},
        "display": {"T": lambda x: 1 - x, "E": lambda x: 1 - x, "M": lambda x: 1 - x}
    },
    "ivscc-EM": {
        "query": {"platforms": ["EM"], "formats": [("arbors", "ivscc",)]},
        "modalities": ["M"],
        "loss": {
            "formats": {"M": ["ivscc"]},
            "losses": {"ivscc": "sample_r2"},
            "transform": {}},
        "groups": {"ivscc"},
        "display": {"M": lambda x: 1 - x}
    },
    "ivscc-dual-patchseq": {
        "query": {"formats": [("logcpm", "pca-ipfx", "arbors", "ivscc")]},
        "modalities": ["T", "E", "M"],
        "loss": {
            "formats": {"T": ["logcpm"], "E": ["pca-ipfx"], "M": ["arbors", "ivscc"]},
            "losses": {"logcpm": "feature_r2", "pca-ipfx": "feature_r2", "arbors": "sample_r2", "ivscc": "sample_r2"},
            "transform": {}},
        "groups": {"dual"},
        "display": {"T": lambda x: 1 - x, "E": lambda x: 1 - x, "M": lambda x: 1 - x}
    },
    "ivscc-dual-EM": {
        "query": {"platforms": ["EM"], "formats": [("arbors", "ivscc")]},
        "modalities": ["M"],
        "loss": {
            "formats": {"M": ["arbors", "ivscc"]},
            "losses": {"arbors": "sample_r2", "ivscc": "sample_r2"},
            "transform": {}},
        "groups": {"dual"},
        "display": {"M": lambda x: 1 - x}
    },
    "patchseq-with-ivscc": {
        "query": {"formats": [("logcpm", "pca-ipfx", "arbors", "ivscc")]},
        "modalities": ["T", "E", "M"],
        "loss": {
            "formats": {"T": ["logcpm"], "E": ["pca-ipfx"], "M": ["arbors"]},
            "losses": {"logcpm": "feature_r2", "pca-ipfx": "feature_r2", "arbors": "sample_r2"},
            "transform": {}},
        "groups": {"patch"},
        "display": {"T": lambda x: 1 - x, "E": lambda x: 1 - x, "M": lambda x: 1 - x}
    }
}

# %%
ivscc_plan = generate_recon_plan([("ivscc-patchseq", "ivscc", None)], ivscc_targets)
ivscc_accs = run_recon_plan(ivscc_plan, ivscc_targets, met_data, all_experiments)
ivscc_scores = compute_scores(ivscc_accs)
# Out:
# Running target ivscc-patchseq:
# Generating met-ivscc - 10: T -> T
# Complete

# %% [markdown]
# #### R2 Table

# %%
ivscc_columns = [
           ("M->T", "ivscc-patchseq", "morph->T"), ("M->T", "patchseq-with-ivscc", "arbors->T"), ("M->T", "ivscc-dual-patchseq", "dual->T"),
           ("M->E", "ivscc-patchseq", "morph->E"), ("M->E", "patchseq-with-ivscc", "arbors->E"), ("M->E", "ivscc-dual-patchseq", "dual->E"),
           ("M->M", "ivscc-patchseq", "morph->morph"), ("M->M", "ivscc-EM", "morph->morph (EM)")]
build_table(ivscc_scores, ivscc_columns, ["patch", "ivscc", "dual"], 2)
# Out:
#                     morph->T  arbors->T    dual->T   morph->E  arbors->E  \
# t_m_arms-patch            --  0.15±0.03         --         --         --
# e_m_arms-patch            --         --         --         --  0.08±0.13
# met-patch                 --  0.13±0.03         --         --  0.15±0.08
# m_arm_ivscc-ivscc         --         --         --         --         --
# met_ivscc-ivscc    0.21±0.02         --         --  0.21±0.07         --
# m_arm_full-ivscc          --         --         --         --         --
# met_full-ivscc     0.22±0.02         --         --  0.23±0.07         --
# met_dual-dual             --         --  0.21±0.02         --         --
#
#                      dual->E morph->morph morph->morph (EM)
# t_m_arms-patch            --           --                --
# e_m_arms-patch            --           --                --
# met-patch                 --           --                --
# m_arm_ivscc-ivscc         --    0.58±0.03        -0.49±0.24
# met_ivscc-ivscc           --     0.5±0.04        -1.35±0.51
# m_arm_full-ivscc          --    0.48±0.03         0.68±0.01
# met_full-ivscc            --    0.42±0.04         0.53±0.03
# met_dual-dual      0.21±0.08           --                --

# %% [markdown]
# ## Comparison of Arbor Densities

# %%
targets = {
    "patchseq": {
        "query": {"formats": [("logcpm", "pca-ipfx", "arbors")]},
        "modalities": ["T", "E", "M"],
        "loss": {
            "formats": {"T": ["logcpm"], "E": ["pca-ipfx"], "M": ["arbors"]},
            "losses": {"logcpm": "sample_r2", "pca-ipfx": "sample_r2", "arbors": "sample_r2"},
            "transform": {}},
        "groups": {"densities"},
        "display": {"T": lambda x: 1 - x, "E": lambda x: 1 - x, "M": lambda x: 1 - x}}
}

# %%
(hist_accs, hist_scores) = ({}, {})
sizes = [(120, 1, 4, 1000), (120, 4, 4, 1000), (120, 8, 4, 1000), (120, 16, 4, 1000), (120, 32, 4, 1000), (120, 64, 4, 1000), 
         (120, 120, 4, 1000), (5, 4, 4, 1000), (10, 4, 4, 1000), (25, 4, 4, 1000), (50, 4, 4, 1000), (200, 4, 4, 1000), (120, 4, 1, 1000), 
         (1, 1, 4, 1000), (120, 4, 4, 100), (120, 4, 4, 500), (120, 4, 4, 2000), (120, 32, 4, 100), (120, 32, 4, 250), (120, 32, 4, 500)]
for (height, radius, arbors, scale) in sizes:
    size_suffix = "" if scale == 1000 else f"_{scale}"
    dataset_folders = {
      "logcpm": "../data/transcriptomics",
      "pca-ipfx": "../data/electrophysiology",
      "arbors": f"../data/morphology/densities/{height}_{radius}_{arbors}{size_suffix}/histogram"}
    met_data_radius = MET_Data("../data/meta/specimens.csv", **dataset_folders)
    specified = [("patchseq", "densities", f"{height}_{radius}_{arbors}{size_suffix}-densities")]
    plan = generate_recon_plan(specified, targets)
    accs = run_recon_plan(plan, targets, met_data_radius, all_experiments, hist_accs)
    scores = compute_scores(accs)
    hist_scores.update(scores)
# Out:
# Running target patchseq:
# Generating 120_1_4-densities - 10: T -> T
# Complete
#
# Running target patchseq:
# Generating 120_4_4-densities - 10: T -> T
# Complete
#
# Running target patchseq:
# Generating 120_8_4-densities - 10: T -> T
# Complete
#
# Running target patchseq:
# Generating 120_16_4-densities - 10: T -> T
# Complete
#
# Running target patchseq:
# Generating 120_32_4-densities - 10: T -> T
# Complete
#
# Running target patchseq:
# Generating 120_64_4-densities - 10: T -> T
# Complete
#
# Running target patchseq:
# Generating 120_120_4-densities - 10: T -> T
# Complete
#
# Running target patchseq:
# Generating 5_4_4-densities - 10: T -> T
# Complete
#
# Running target patchseq:
# Generating 10_4_4-densities - 10: T -> T
# Complete
#
# Running target patchseq:
# Generating 25_4_4-densities - 10: T -> T
# Complete
#
# Running target patchseq:
# Generating 50_4_4-densities - 10: T -> T
# Complete
#
# Running target patchseq:
# Generating 200_4_4-densities - 10: T -> T
# Complete
#
# Running target patchseq:
# Generating 120_4_1-densities - 10: T -> T
# Complete
#
# Running target patchseq:
# Generating 1_1_4-densities - 10: T -> T
# Complete
#
# Running target patchseq:
# Generating 120_4_4_100-densities - 10: T -> T
# Complete
#
# Running target patchseq:
# Generating 120_4_4_500-densities - 10: T -> T
# Complete
#
# Running target patchseq:
# Generating 120_4_4_2000-densities - 10: T -> T
# Complete
#
# Running target patchseq:
# Generating 120_32_4_100-densities - 10: T -> T
# Complete
#
# Running target patchseq:
# Generating 120_32_4_250-densities - 10: T -> T
# Complete
#
# Running target patchseq:
# Generating 120_32_4_500-densities - 10: T -> T
# Complete

# %%
hist_scores
# Out:
# {'patchseq': {'densities': {'120_1_4-densities': {'mean': {'E->E': 0.33595682694460766,
#      'E->M': 0.14452575525895378,
#      'E->T': 0.21798711857891612,
#      'M->E': 0.1675874796745299,
#      'M->M': 0.7297085929502277,
#      'M->T': 0.17088173499055,
#      'T->E': 0.31842935560513774,
#      'T->M': 0.35253110500220497,
#      'T->T': 0.3074405885105021},
#     'std': {'E->E': 0.049277719221616556,
#      'E->M': 0.03175127646630326,
#      'E->T': 0.013083470097478976,
#      'M->E': 0.06250201362016251,
#      'M->M': 0.014050768527818665,
#      'M->T': 0.011579921314666914,
#      'T->E': 0.04983837259699757,
#      'T->M': 0.039493360487296104,
#      'T->T': 0.01450390896978261}},
#    '120_4_4-densities': {'mean': {'E->E': 0.3352267307429185,
#      'E->M': 0.14431437283724521,
#      'E->T': 0.22280158559652988,
#      'M->E': 0.1772453888326127,
#      'M->M': 0.7270241403279376,
#      'M->T': 0.17782155541840128,
#      'T->E': 0.32085593836367043,
#      'T->M': 0.34469442174090076,
#      'T->T': 0.3106101757950455},
#     'std': {'E->E': 0.041260716473109624,
#      'E->M': 0.039075755537773336,
#      'E->T': 0.013873851161308714,
#      'M->E': 0.0704922541364751,
#      'M->M': 0.011473124324820444,
#      'M->T': 0.013953409124744897,
#      'T->E': 0.04802336031180466,
#      'T->M': 0.0374865330175804,
#      'T->T': 0.011178849461718841}},
#    '120_8_4-densities': {'mean': {'E->E': 0.34096175887095576,
#      'E->M': 0.10076497276611134,
#      'E->T': 0.22384146418077072,
#      'M->E': 0.18693440128315797,
#      'M->M': 0.7052593005281189,
#      'M->T': 0.18126284131557274,
#      'T->E': 0.32371442917822774,
#      'T->M': 0.3080677975157316,
#      'T->T': 0.31357282049469143},
#     'std': {'E->E': 0.0421711968816488,
#      'E->M': 0.04898778023467356,
#      'E->T': 0.01592827201663229,
#      'M->E': 0.05474987946759814,
#      'M->M': 0.012481918209496975,
#      'M->T': 0.013458449316619133,
#      'T->E': 0.04364820451290537,
#      'T->M': 0.03952703904392265,
#      'T->T': 0.01311670215439231}},
#    '120_16_4-densities': {'mean': {'E->E': 0.3494664457576576,
#      'E->M': 0.07924518887296651,
#      'E->T': 0.2279159416224253,
#      'M->E': 0.18055258020470527,
#      'M->M': 0.6244936892847741,
#      'M->T': 0.17188886767472406,
#      'T->E': 0.3244243059598492,
#      'T->M': 0.23755315489314272,
#      'T->T': 0.3062048636496194},
#     'std': {'E->E': 0.04281085712329061,
#      'E->M': 0.038837137902182316,
#      'E->T': 0.017504010626698163,
#      'M->E': 0.06113772384155887,
#      'M->M': 0.020173584826924124,
#      'M->T': 0.01496003133438766,
#      'T->E': 0.04691508887174161,
#      'T->M': 0.04149418990728322,
#      'T->T': 0.010171864612031336}},
#    '120_32_4-densities': {'mean': {'E->E': 0.3550199974135398,
#      'E->M': 0.008840485139760346,
#      'E->T': 0.22932562731571382,
#      'M->E': 0.18057518887274654,
#      'M->M': 0.5027818079388131,
#      'M->T': 0.1675986148429894,
#      'T->E': 0.3246442525984734,
#      'T->M': 0.15011756302873672,
#      'T->T': 0.3050370880913207},
#     'std': {'E->E': 0.038497984776889226,
#      'E->M': 0.05895124931324114,
#      'E->T': 0.014993930777315659,
#      'M->E': 0.05936174649989752,
#      'M->M': 0.023318469710547553,
#      'M->T': 0.023096514055037057,
#      'T->E': 0.04371576487635482,
#      'T->M': 0.043248235959553134,
#      'T->T': 0.0164441024427616}},
#    '120_64_4-densities': {'mean': {'E->E': 0.3622040263872206,
#      'E->M': 0.016201103676994844,
#      'E->T': 0.2320043395533689,
#      'M->E': 0.17850199818427553,
#      'M->M': 0.34653196780758283,
#      'M->T': 0.16104486946157653,
#      'T->E': 0.32037594323539287,
#      'T->M': 0.10315631067493443,
#      'T->T': 0.304219857378431},
#     'std': {'E->E': 0.04819730278835168,
#      'E->M': 0.044531063305612024,
#      'E->T': 0.019875199939741475,
#      'M->E': 0.05762573796915722,
#      'M->M': 0.026900918687470708,
#      'M->T': 0.018735115787989164,
#      'T->E': 0.053024776907409706,
#      'T->M': 0.033965351445268854,
#      'T->T': 0.017479162364547593}},
#    '120_120_4-densities': {'mean': {'E->E': 0.3728216717232004,
#      'E->M': -0.0014780902259606155,
#      'E->T': 0.24743442677047542,
#      'M->E': 0.16188224017820413,
#      'M->M': 0.21105753170979225,
#      'M->T': 0.15626952796559798,
#      'T->E': 0.3265480512957146,
#      'T->M': 0.05607661540337892,
#      'T->T': 0.318390758207852},
#     'std': {'E->E': 0.042665681056967907,
#      'E->M': 0.031362148539171235,
#      'E->T': 0.014871997163020205,
#      'M->E': 0.05298104621297531,
#      'M->M': 0.02830985564367813,
#      'M->T': 0.019679495433217925,
#      'T->E': 0.046722783160208926,
#      'T->M': 0.03703762343292543,
#      'T->T': 0.014266901823247833}},
#    '5_4_4-densities': {'mean': {'E->E': 0.255695166588248,
#      'E->M': 0.34918657962330213,
#      'E->T': 0.15818770886297184,
#      'M->E': 0.16679222641917044,
#      'M->M': 0.9556654215171347,
#      'M->T': 0.15503251111119337,
#      'T->E': 0.2850192749051107,
#      'T->M': 0.6109225452275638,
#      'T->T': 0.26391950100270245},
#     'std': {'E->E': 0.04768868762502017,
#      'E->M': 0.05395700121951607,
#      'E->T': 0.04361116168268801,
#      'M->E': 0.05695989687088395,
#      'M->M': 0.012674513584488494,
#      'M->T': 0.03941864504330495,
#      'T->E': 0.049462325690004215,
#      'T->M': 0.04022634152751026,
#      'T->T': 0.04182465252671974}},
#    '10_4_4-densities': {'mean': {'E->E': 0.27340164903075465,
#      'E->M': 0.23196696016554155,
#      'E->T': 0.17040220380479942,
#      'M->E': 0.17176665314562983,
#      'M->M': 0.9182694891677207,
#      'M->T': 0.1725200584289998,
#      'T->E': 0.2979589729772229,
#      'T->M': 0.49295161031514245,
#      'T->T': 0.2910644213552945},
#     'std': {'E->E': 0.04304622553093336,
#      'E->M': 0.05525875751840702,
#      'E->T': 0.023802284487569842,
#      'M->E': 0.06033766699111656,
#      'M->M': 0.012049665475280543,
#      'M->T': 0.011635831766457048,
#      'T->E': 0.046641472782329295,
#      'T->M': 0.03933675318333861,
#      'T->T': 0.010275510222197633}},
#    '25_4_4-densities': {'mean': {'E->E': 0.2883150056217992,
#      'E->M': 0.15661683997796175,
#      'E->T': 0.18132343936798284,
#      'M->E': 0.17977502617461627,
#      'M->M': 0.844732291256243,
#      'M->T': 0.16923522969453023,
#      'T->E': 0.29953383521932564,
#      'T->M': 0.40048035827906353,
#      'T->T': 0.28365776065122306},
#     'std': {'E->E': 0.043064662049027286,
#      'E->M': 0.04288296252167363,
#      'E->T': 0.027522943495889674,
#      'M->E': 0.05433224947488817,
#      'M->M': 0.026568705673913683,
#      'M->T': 0.01743244832008143,
#      'T->E': 0.0529643239481005,
#      'T->M': 0.027137279311421042,
#      'T->T': 0.028835236402517676}},
#    '50_4_4-densities': {'mean': {'E->E': 0.3156917368043729,
#      'E->M': 0.13741632155046293,
#      'E->T': 0.1994899997765885,
#      'M->E': 0.17638550383793555,
#      'M->M': 0.7877440391557828,
#      'M->T': 0.16845768110231446,
#      'T->E': 0.3094361095590369,
#      'T->M': 0.35718355663290424,
#      'T->T': 0.29259987727296555},
#     'std': {'E->E': 0.05065684435214029,
#      'E->M': 0.04661677187431264,
#      'E->T': 0.01939388623697982,
#      'M->E': 0.05978590805282931,
#      'M->M': 0.016266019735471454,
#      'M->T': 0.021945608147400382,
#      'T->E': 0.05107033247383945,
#      'T->M': 0.028710731233484624,
#      'T->T': 0.016115417720371263}},
#    '200_4_4-densities': {'mean': {'E->E': 0.35461827343291985,
#      'E->M': 0.15194989723638627,
#      'E->T': 0.23759188376576934,
#      'M->E': 0.16928087883032106,
#      'M->M': 0.6906006232670896,
#      'M->T': 0.1693413164221389,
#      'T->E': 0.32783831861295837,
#      'T->M': 0.32997757959819923,
#      'T->T': 0.31894418992870993},
#     'std': {'E->E': 0.041250621219263844,
#      'E->M': 0.04173969947961976,
#      'E->T': 0.018366022747887588,
#      'M->E': 0.06242310851532747,
#      'M->M': 0.014160479415998862,
#      'M->T': 0.013782508918934651,
#      'T->E': 0.04807108774876837,
#      'T->M': 0.03276763330886956,
#      'T->T': 0.011639793147849265}},
#    '120_4_1-densities': {'mean': {'E->E': 0.3205009938974924,
#      'E->M': 0.13403040437572528,
#      'E->T': 0.20856004315083684,
#      'M->E': 0.09583488789843848,
#      'M->M': 0.7923518352686012,
#      'M->T': 0.09065179073616988,
#      'T->E': 0.3156476381669922,
#      'T->M': 0.3655767772885402,
#      'T->T': 0.30262331609626925},
#     'std': {'E->E': 0.04656623307958259,
#      'E->M': 0.0640738100180884,
#      'E->T': 0.025564468354259615,
#      'M->E': 0.06897676475258224,
#      'M->M': 0.012695693713495352,
#      'M->T': 0.021467402845132197,
#      'T->E': 0.046693108095102465,
#      'T->M': 0.04486650958530243,
#      'T->T': 0.026079452408499664}},
#    '1_1_4-densities': {'mean': {'E->E': 0.39792094933880445,
#      'E->M': 0.7497286182380429,
#      'E->T': 0.24827406043567515,
#      'M->E': 0.11044989515367346,
#      'M->M': 0.7539291350965083,
#      'M->T': 0.08540427700413208,
#      'T->E': 0.32619852491209755,
#      'T->M': 0.7499230710582239,
#      'T->T': 0.3221128021265046},
#     'std': {'E->E': 0.04766694500461362,
#      'E->M': 0.33302076581045253,
#      'E->T': 0.019923015134688464,
#      'M->E': 0.05901814718522673,
#      'M->M': 0.3327809395859871,
#      'M->T': 0.011444941645597846,
#      'T->E': 0.04643491498256139,
#      'T->M': 0.33317577535923043,
#      'T->T': 0.030434434142126602}}}}}

# %%
build_table(hist_scores, [
    ("T->T", "patchseq", "T->T"), ("E->T", "patchseq", "E->T"), ("M->T", "patchseq", "M->T"), ("E->E", "patchseq", "E->E"), 
    ("T->E", "patchseq", "T->E"), ("M->E", "patchseq", "M->E"), ("M->M", "patchseq", "M->M"), ("T->M", "patchseq", "T->M"), 
    ("E->M", "patchseq", "E->M")], 
            ["densities"], 2)
# Out:
#                           T->T       E->T       M->T       E->E       T->E  \
# 120_1_4-densities    0.31±0.01  0.22±0.01  0.17±0.01  0.34±0.05  0.32±0.05
# 120_4_4-densities    0.31±0.01  0.22±0.01  0.18±0.01  0.34±0.04  0.32±0.05
# 120_8_4-densities    0.31±0.01  0.22±0.02  0.18±0.01  0.34±0.04  0.32±0.04
# 120_16_4-densities   0.31±0.01  0.23±0.02  0.17±0.01  0.35±0.04  0.32±0.05
# 120_32_4-densities   0.31±0.02  0.23±0.01  0.17±0.02  0.36±0.04  0.32±0.04
# 120_64_4-densities    0.3±0.02  0.23±0.02  0.16±0.02  0.36±0.05  0.32±0.05
# 120_120_4-densities  0.32±0.01  0.25±0.01  0.16±0.02  0.37±0.04  0.33±0.05
# 5_4_4-densities      0.26±0.04  0.16±0.04  0.16±0.04  0.26±0.05  0.29±0.05
# 10_4_4-densities     0.29±0.01  0.17±0.02  0.17±0.01  0.27±0.04   0.3±0.05
# 25_4_4-densities     0.28±0.03  0.18±0.03  0.17±0.02  0.29±0.04   0.3±0.05
# 50_4_4-densities     0.29±0.02   0.2±0.02  0.17±0.02  0.32±0.05  0.31±0.05
# 200_4_4-densities    0.32±0.01  0.24±0.02  0.17±0.01  0.35±0.04  0.33±0.05
# 120_4_1-densities     0.3±0.03  0.21±0.03  0.09±0.02  0.32±0.05  0.32±0.05
# 1_1_4-densities      0.32±0.03  0.25±0.02  0.09±0.01   0.4±0.05  0.33±0.05
#
#                           M->E       M->M       T->M       E->M
# 120_1_4-densities    0.17±0.06  0.73±0.01  0.35±0.04  0.14±0.03
# 120_4_4-densities    0.18±0.07  0.73±0.01  0.34±0.04  0.14±0.04
# 120_8_4-densities    0.19±0.05  0.71±0.01  0.31±0.04   0.1±0.05
# 120_16_4-densities   0.18±0.06  0.62±0.02  0.24±0.04  0.08±0.04
# 120_32_4-densities   0.18±0.06   0.5±0.02  0.15±0.04  0.01±0.06
# 120_64_4-densities   0.18±0.06  0.35±0.03   0.1±0.03  0.02±0.04
# 120_120_4-densities  0.16±0.05  0.21±0.03  0.06±0.04  -0.0±0.03
# 5_4_4-densities      0.17±0.06  0.96±0.01  0.61±0.04  0.35±0.05
# 10_4_4-densities     0.17±0.06  0.92±0.01  0.49±0.04  0.23±0.06
# 25_4_4-densities     0.18±0.05  0.84±0.03   0.4±0.03  0.16±0.04
# 50_4_4-densities     0.18±0.06  0.79±0.02  0.36±0.03  0.14±0.05
# 200_4_4-densities    0.17±0.06  0.69±0.01  0.33±0.03  0.15±0.04
# 120_4_1-densities     0.1±0.07  0.79±0.01  0.37±0.04  0.13±0.06
# 1_1_4-densities      0.11±0.06  0.75±0.33  0.75±0.33  0.75±0.33

# %% [markdown]
# ## Reconstruction via T-Type

# %% [markdown]
# ### Setup

# %%
def get_ttype_mse(met_data, train_ids, test_ids):
    mse = {}
    merge_map = utils.get_tree_merge_map("../data/meta/tree_Mouse_ALM-VISp_2018.csv", "n3")
    mappers = {merge: np.vectorize(lambda elem,merge=merge: merge_map[elem][merge]) 
               for merge in range(len(next(iter(merge_map.values()))) - 1)}
    for form in ["logcpm", "pca-ipfx", "arbors"]:
        train_data = met_data.query(train_ids, platforms = ["patchseq"], formats = [("logcpm", form)], 
                                    outputs = [form, "cluster_label", "specimen_id"])
        test_data = met_data.query(test_ids, platforms = ["patchseq"], formats = [("logcpm", "pca-ipfx", "arbors")], 
                                   outputs = [form, "cluster_label", "specimen_id"])
        (train_clusters, test_clusters) = (np.char.strip(train_data["cluster_label"]), np.char.strip(test_data["cluster_label"]))
        for (merge, map_func) in mappers.items():
            (train_clusters, test_clusters) = (map_func(train_clusters), map_func(test_clusters))
            (train_labels, test_labels) = (np.unique(train_clusters), np.unique(test_clusters))
            (train_masks, test_masks) = (train_labels[:, None] == train_clusters[None], test_labels[:, None] == test_clusters[None])
            label_means = {label: np.mean(train_data[form][mask], 0) for (label, mask) in zip(train_labels, train_masks)}
            label_mse = sum([np.square(label_means[label][None] - test_data[form][mask]).sum() 
                             for (label, mask) in zip(test_labels, test_masks)])
            mse.setdefault(form, []).append(label_mse / len(test_data["specimen_id"]))
    return mse

# %%
def get_ttype_r2(met_data, train_ids, test_ids, loss_config):
    r2 = {}
    merge_map = utils.get_tree_merge_map("../data/meta/tree_Mouse_ALM-VISp_2018.csv", "n3")
    mappers = {merge: np.vectorize(lambda elem,merge=merge: merge_map[elem][merge]) 
               for merge in range(len(next(iter(merge_map.values()))) - 1)}
    for form in ["logcpm", "pca-ipfx", "arbors"]:
        train_data = met_data.query(train_ids, platforms = ["patchseq"], formats = [("logcpm", form)], 
                                    outputs = [form, "cluster_label", "specimen_id"])
        test_data = met_data.query(test_ids, platforms = ["patchseq"], formats = [("logcpm", "pca-ipfx", "arbors")], 
                                   outputs = [form, "cluster_label", "specimen_id"])
        loss_func = ReconstructionLoss(loss_config, met_data, np.concatenate([train_data["specimen_id"], test_data["specimen_id"]]))
        (train_clusters, test_clusters) = (np.char.strip(train_data["cluster_label"]), np.char.strip(test_data["cluster_label"]))
        for (merge, map_func) in mappers.items():
            (train_clusters, test_clusters) = (map_func(train_clusters), map_func(test_clusters))
            (train_labels, test_labels) = (np.unique(train_clusters), np.unique(test_clusters))
            (train_masks, test_masks) = (train_labels[:, None] == train_clusters[None], test_labels[:, None] == test_clusters[None])
            label_means = {label: np.mean(train_data[form][mask], 0) for (label, mask) in zip(train_labels, train_masks)}
            recon = torch.from_numpy(np.stack([label_means[label] for label in test_clusters], 0))
            label_r2 = 1 - loss_func.loss({form: torch.from_numpy(test_data[form])}, {form: recon})
            r2.setdefault(form, []).append(label_r2.numpy())
    return r2

# %% [markdown]
# ### R2

# %%
loss_config = {
    "encoder_cross_grad": False, 
    "device": "cpu", 
    "formats": {"T": ["logcpm"], "E": ["pca-ipfx"], "M": ["arbors"]},
    "losses": {"logcpm": "feature_r2", "pca-ipfx": "feature_r2", "arbors": "sample_r2"},
    "transform": {}}

# %%
exp = "met-ref"
folds = all_experiments[exp.split("-")[-1]][exp]["folds"]
r2_curves = {}
for (fold, fold_dict) in folds.items():
    print(fold, end = "\r")
    (train_ids, test_ids) = (fold_dict["train_ids"], fold_dict["test_ids"])
    try:
        r2_dict = get_ttype_r2(met_data, train_ids, test_ids, loss_config)
        for (form, r2_scores) in r2_dict.items():
            for (merges, r2) in enumerate(r2_scores):
                r2_curves.setdefault(form, {}).setdefault(merges, []).append(r2)
    except KeyError as e:
        print(repr(e))
cluster_ideal = {}
for (form, merge_dict) in r2_curves.items():
    for (merge, fold_r2s) in merge_dict.items():
        data_dict = cluster_ideal.setdefault(form, {}).setdefault(merge, {})
        data_dict["mean"] = np.mean(fold_r2s)
        data_dict["std"] = np.std(fold_r2s)
# Out:
# KeyError('Lamp5 Fam19a1 Tmem182')
# KeyError('Vip Arhgap36 Hmcn1')
# 10

# %% [markdown]
# ### Ratio

# %%
exps = ["met_et_4x_MET-weighted", "met_et_4x_patch-weighted", "met_et_4x-weighted"]
all_exp_ratios = {}
for exp in exps:
    folds = all_experiments[exp.split("-")[-1]][exp]["folds"]
    ratio_dict = {}
    for (fold, fold_dict) in folds.items():
        print(f"{exp} - {fold}                   ", end = "\r")
        (train_ids, test_ids) = (fold_dict["train_ids"], fold_dict["test_ids"])
        model = fold_dict["best"]
        test_data = met_data.query(test_ids, platforms = ["patchseq"], formats = [("logcpm", "pca-ipfx", "arbors")])
        try:
            ttype_mse_dict = get_ttype_mse(met_data, train_ids, test_ids)
        except KeyError as e:
            print(repr(e))
        for (in_modal, in_form) in [("T", "logcpm"), ("E", "pca-ipfx"), ("M", "arbors")]:
            for (out_modal, out_form) in [("T", "logcpm"), ("E", "pca-ipfx"), ("M", "arbors")]:
                (in_data, out_data) = (test_data[in_form], test_data[out_form])
                model_recon = model({in_form: torch.from_numpy(in_data).float()}, in_modal, [out_modal])[out_modal][out_form].numpy(force = True)
                model_mse = np.square(model_recon - out_data).mean(0).sum()
                ratios = [model_mse / ttype_mse for ttype_mse in ttype_mse_dict[out_form]]
                for (merges, ratio) in enumerate(ratios):
                    ratio_dict.setdefault(in_modal, {}).setdefault(out_modal, {}).setdefault(merges, []).append(ratio)
    all_exp_ratios[exp] = ratio_dict
# Out:
# KeyError('Lamp5 Fam19a1 Tmem182')
# KeyError('Lamp5 Krt73')- 9
# KeyError('Vip Arhgap36 Hmcn1')
# KeyError('Lamp5 Fam19a1 Tmem182')
# KeyError('Lamp5 Krt73')d - 9
# KeyError('Vip Arhgap36 Hmcn1')
# KeyError('Lamp5 Fam19a1 Tmem182')
# KeyError('Lamp5 Krt73')
# KeyError('Vip Arhgap36 Hmcn1')

# %%
plot_data = {"Experiment": [], "Input Modality": [], "Output Modality": [], "Merges": [], "VAE / T-Type MSE Ratio": [], "Fold": []}
for (exp, ratio_dict) in all_exp_ratios.items():
    for (in_modal, out_dict) in ratio_dict.items():
        for (out_modal, merge_dict) in out_dict.items():
            for (num_merges, fold_ratios) in merge_dict.items():
                for (fold, ratio) in enumerate(fold_ratios):
                    plot_data["Experiment"].append(exp)
                    plot_data["Input Modality"].append(in_modal)
                    plot_data["Output Modality"].append(out_modal)
                    plot_data["Merges"].append(num_merges)
                    plot_data["VAE / T-Type MSE Ratio"].append(ratio)
                    plot_data["Fold"].append(fold)
grid = sns.relplot(data = plot_data, x = "Merges", y = "VAE / T-Type MSE Ratio", col = "Input Modality", row = "Output Modality", hue = "Experiment", 
                   kind = "line", aspect = 1.5, height = 3)
for ax_row in grid.axes:
    for ax in ax_row:
        ax.axhline(1.0, color = "black", linestyle = "dashed", linewidth = 1)
plt.savefig("ratios.png", dpi = 1000.0)
plt.show()

# %%
plot_data = {"Input Modality": [], "Output Modality": [], "Merges": [], "VAE / T-Type MSE Ratio": [], "Fold": []}
for (in_modal, out_dict) in ratio_dict.items():
    for (out_modal, merge_dict) in out_dict.items():
        for (num_merges, fold_ratios) in merge_dict.items():
            for (fold, ratio) in enumerate(fold_ratios):
                plot_data["Input Modality"].append(in_modal)
                plot_data["Output Modality"].append(out_modal)
                plot_data["Merges"].append(num_merges)
                plot_data["VAE / T-Type MSE Ratio"].append(ratio)
                plot_data["Fold"].append(fold)
grid = sns.relplot(data = plot_data, x = "Merges", y = "VAE / T-Type MSE Ratio", col = "Input Modality", row = "Output Modality", 
                   kind = "line")
for ax_row in grid.axes:
    for ax in ax_row:
        ax.axhline(1.0, color = "black", linestyle = "dashed", linewidth = 1)
plt.savefig("ratios.png", dpi = 1000.0)
plt.show()

# %%
plot_data = {"Input Modality": [], "Output Modality": [], "Merges": [], "VAE / T-Type MSE Ratio": [], "Fold": []}
for (in_modal, out_dict) in ratio_dict.items():
    for (out_modal, merge_dict) in out_dict.items():
        for (num_merges, fold_ratios) in merge_dict.items():
            for (fold, ratio) in enumerate(fold_ratios):
                plot_data["Input Modality"].append(in_modal)
                plot_data["Output Modality"].append(out_modal)
                plot_data["Merges"].append(num_merges)
                plot_data["VAE / T-Type MSE Ratio"].append(ratio)
                plot_data["Fold"].append(fold)
grid = sns.relplot(data = plot_data, x = "Merges", y = "VAE / T-Type MSE Ratio", col = "Input Modality", row = "Output Modality", 
                   kind = "line")
for ax_row in grid.axes:
    for ax in ax_row:
        ax.axhline(1.0, color = "black", linestyle = "dashed", linewidth = 1)
# plt.savefig("vae_vs_ttype_r2.pdf")
plt.show()

# %%
plot_data = {"Input Modality": [], "Output Modality": [], "Merges": [], "VAE / T-Type MSE Ratio": [], "Fold": []}
for (in_modal, out_dict) in ratio_dict.items():
    for (out_modal, merge_dict) in out_dict.items():
        for (num_merges, fold_ratios) in merge_dict.items():
            for (fold, ratio) in enumerate(fold_ratios):
                plot_data["Input Modality"].append(in_modal)
                plot_data["Output Modality"].append(out_modal)
                plot_data["Merges"].append(num_merges)
                plot_data["VAE / T-Type MSE Ratio"].append(ratio)
                plot_data["Fold"].append(fold)
grid = sns.relplot(data = plot_data, x = "Merges", y = "VAE / T-Type MSE Ratio", col = "Input Modality", row = "Output Modality", 
                   kind = "line")
for ax_row in grid.axes:
    for ax in ax_row:
        ax.axhline(1.0, color = "black", linestyle = "dashed", linewidth = 1)
plt.savefig("vae_vs_ttype_r2.pdf")
plt.show()
